# %%
import pandas as pd
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
#pd.options.display.max_colwidth = 200

# %%
#!pip install pandas

# %%
data = pd.read_csv('tags.csv')
data = data.drop(columns = {'Unnamed: 0'})
data
# Out:
#                                     drink_name  \
# 0                                #106 Cocktail
# 1         '57 Chevy with a White License Plate
# 2                               1-900-FUK-MEUP
# 3                                      10 to 7
# 4                             110 in the shade
# ...                                        ...
# 1712                                    Zoksel
# 1713                                    Zombie
# 1714                                 Zorbatini
# 1715                                     Zorro
# 1716  “Prepare for Destiny! Where’s my Pizza?”
#
#                                            instructions  steps  \
# 0     Shake and double strain into a coupe. Garnish ...      4
# 1     1. Fill a rocks glass with ice 2.add white cre...      3
# 2     Shake ingredients in a mixing tin filled with ...      2
# 3     Shake and serve up in a martini glass with lem...      1
# 4                 Drop shooter in glass. Fill with beer      1
# ...

# %% [markdown]
# ### Adding Picture Links

# %%
#Drinks to find pictures for
data[pd.isna(data['picture'])]['drink_name'][317:]
# Out:
# 1357                             Simply Perfecto
# 1359               Singapore Sling (1915 Recipe)
# 1362                               Sloe & Steady
# 1364                                   Slow Ride
# 1365                     Smashing Great Pumpkins
#                           ...
# 1697                            You Go Glen Coco
# 1698                     You're Bitter Than That
# 1699                          Ypioca Chile Punch
# 1700                          Ypioca Yellow Card
# 1716    “Prepare for Destiny! Where’s my Pizza?”
# Name: drink_name, Length: 163, dtype: object

# %%
#Drinks to find pictures for
data[pd.isna(data['picture'])]
# Out:
#                                     drink_name  \
# 24                              A Bloody Shame
# 25                          A Botanical Garden
# 28                            A Gift from Zara
# 30                                 A Love Song
# 31            A Mi Manera (My Way) Pisco Punch
# ...                                        ...
# 1697                          You Go Glen Coco
# 1698                   You're Bitter Than That
# 1699                        Ypioca Chile Punch
# 1700                        Ypioca Yellow Card
# 1716  “Prepare for Destiny! Where’s my Pizza?”
#
#                                            instructions  steps picture tags  \
# 24    Shaken and strained into a large coupe. Garnis...      4     NaN  NaN
# 25    Combine all ingredients in a shaking tin and g...      2     NaN  NaN
# 28    Build all ingredients except for the Topo Chic...      4     NaN  NaN
# 30    Combine all ingredients besides blood orange i...      3     NaN  NaN
# ...

# %%
def add_picture_links(data):
    lst = [('Apple Banana Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_apple_banana_smoothie-1.png'),
           ('Avo-Banana Kale Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_avo_banana_kale-1.png'),
           ('Avocado Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_avocado_smoothie-1.png'),
           ('Banana Blackberry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_banana_blackberry_smoothie-1.png'),
           ('Banana-Ginger Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_banana_ginger-1.png'), 
           ('Basil Strawberry Mango Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_basil_strawberry_mango_smoothie-1.png'),
           ('Berry Berry Blast Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_berry_blast-1.png'),
           ('Black Raspberry-Vanilla Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_black_raspberry_vanilla-1.png'),
           ('Blackberry and Peach Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_blackberry_and_peach_smoothie-1.png'),
           ('Cantaloupe Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_cantaloupe_smoothie-1.png'),
           ('Cherry Banana Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_cherry_banana_smoothie-1.png'),
           ('Cinnapear Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_cinnapear_smoothie-1.png'),
           ('Collard Greens Smoothie with Mango &', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_collard_greens_mango_lime-1.png'),
           ('Creamsicle Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_creamsicle_smoothie-1.png'),
           ('Frozen Blueberry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_frozen_blueberry_smoothie-1.png'),
           ('Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_fruit_smoothie-1.png'),
           ('Fruity Spinach Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_fruity_spinach_smoothie-1.png'),
           ('Ginger Winter Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_ginger_winter_green_smoothie-1.png'),
           ('Gloomy Day Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_gloomy_day_smoothie-1.png'),
           ('Green Envy Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_envy_avocado-1.png'),
           ('Green Julius Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_julius_smoothie-1.png'),
           ('Green Slime Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_slime_smoothie-1.png'),
           ('Green Tea and Honey Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_tea_smoothie-1.png'),
           ('Green Tropics Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_tropics_smoothie-1.png'),
           ('Healthy Green Coconut Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_healthy_green_coconut_smoothie-1.png'),
           ('Healthy Winter Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_healthy_winter_smoothie-1.png'),
           ('Heart Healthy Oat & Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_heart_healthy_oat_and_fruit_smoothie-1.png'),
           ('Honeydew-Almond Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_honeydew_almond-1.png'),
           ('Kale Ginger Detox Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_kale_ginger_detox-1.png'),
           ('Kiwi Berry Punch Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_kiwi_berry_punch-1.png'),
           ('Lean Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_lean_green_smoothie-1.png'),
           ('Mango and Yogurt Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_mango_and_yogurt_smoothie-1.png'),
           ('Mixed Berry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_mixed_berry_smoothie-1.png'),
           ('Nectarine Sunshine Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_nectarine_sunshine_smoothie-1.png'),
           ('Oatmeal & Strawberry Breakfast Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_oatmeal_strawberry-1.png'),
           ('Papaya Surprise Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_papaya_surprise_smoothie-1.png'),
           ('Peach & Coconut Dream Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_peach_coconut_dream_green-1.png'),
           ('Pomegranate Breakfast Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_pomegranate_breakfast_smoothie-1.png'),
           ('Pumpkin Pie Fall Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_pumpkin_pie_fall_smoothie-1.png'),
           ('Purple Cow Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_purple_cow_smoothie-1.png'),
           ('Rainforest Fusion Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_rain_forest_fusion-1.png'),
           ('Raspberry & Banana Smoothie with Flax', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_raspberry_banana_flax-1.png'),
           ('Raspberry Good Peach Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_berry_good_peach-1.png'),
           ('Red, White and Blue Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_red_white_blue_smoothie-1.png'),
           ('Sour Black Cherry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_sour_black_cherry_smoothie-1.png'),
           ('Spa Cucumber Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_spa_cucumber_smoothie-1.png'),
           ('Spinach Smoothie with Avocado & Apple', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_spinach_smoothie_with_avocado_and_apple-1.png'),
           ('Spinach, Grape and Coconut Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_spinach__grape_and_coconut_smoothie-1.png'),
           ('Strawberry Coconut Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_coconut_smoothie-1.png'),
           ('Strawberry Mango Spring Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_mango_spring_smoothie-1.png'),
           ('Strawberry Peach Carrot Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_peach_carrot_smoothie-1.png'),
           ('Strawberry-Kiwi Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_kiwi-1.png'),
           ('Summer Stone Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_summer_stone_fruit_smoothie-1.png'),
           ('Sunshine in a Glass Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_sunshine_ina_jar-1.png'),
           ('Sweet Veggie Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_sweet_veggie_smoothie-1.png'),
           ('Tropical Blueberry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_tropical_blueberry_smoothie-1.png'),
           ('Winter Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_winter_smoothie-1.png'),
           ('Yogurt Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_yogurt_fruit_smoothie-1.png'),
           ('#106 Cocktail', 'https://talesofthecocktail.org/wp-content/uploads/2016/11/106cocktail.jpg'),
           ('10 to 7', 'https://www.inspiredtaste.net/wp-content/uploads/2010/07/Lemon-Drop-Martini-Cocktail-Recipe-2-1200.jpg'),
           ("1880's Americana", 'https://www.thespruceeats.com/thmb/ztnL3iwFJ09ut-XAPAhvFgTsgP8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/old-fashioned-cocktail-recipe-and-history-759328-hero-01-c9002b3aa6d24a3781befa19dc69eb0e.jpg'),
           ('20th Century', 'https://imbibemagazine.com/wp-content/uploads/2019/02/anatomy-20th-century-cocktail-crdt-john-valls-dk.jpg'),
           ('3 & Tree', 'https://mscwordpresscontent.s3.amazonaws.com/wa/wp-content/uploads/2021/07/three-trees.jpg?resize=1920x0'),
           ('3 Degrees', 'https://burrataandbubbles.com/wp-content/uploads/2020/11/pear-sage-gimlet.jpg'),
           ('3AM', 'https://www.shot-cocktail-recipe.com/data/img/glass/3.jpg'),
           ('50/50 Split', 'https://www.liquor.com/thmb/loLyerdf2WBrNUZ6d7_jtJdpwIQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/50-50-martini-1500x1500-hero-e56870ded762483da2406176979cb452.jpg'),
           ('7th Heaven', 'https://www.cupofzest.com/wp-content/uploads/2016/09/Seventh-Heaven-Cocktail-THUMBNAIL.jpg'),
           ('Mandrake', 'https://www.liquor.com/thmb/q9jqGNIOYSisxpCdCeHJv4gdda0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/brandy-sangaree-720x720-primary-bbffe3e005fa4e92bf371d2f397efdf6.jpg'),
           ('Mango No. 3', 'https://thelittlestcrumb.com/wp-content/uploads/mango-tango-drink-3.jpg'),
           ('Maraschino Side Car', 'https://i2.wp.com/www.splashoftaste.com/wp-content/uploads/2022/08/sidecar-drink-10.jpg'),
           ('Marchesa', 'https://i.pinimg.com/736x/db/a3/7e/dba37e3d90e32c2af992f179f95ca167--grappa-stromboli.jpg'),
           ('Maria Canevari Punch', 'https://4.bp.blogspot.com/-qQ7rY5nmObo/VxauXDpWCRI/AAAAAAAAKFs/r1vxSUTAnss57M-nie7JQnsmKsfZHkVFQCLcB/s1600/gastronomista_luxardo_cherry%2Bblossom%2Bmartini_5.jpg'),
           ('Martinez', 'https://www.thespruceeats.com/thmb/wRAzpSZBNFG69NsinBSYSFcUQTo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/martinez-cocktail-recipe-759324-hero-01-6d1091ff153b4e9e92f36ff9f755b544.jpg'),
           ("Masataka's Vision", 'https://cocktailpartyapp.com/wp-content/uploads/Masataka-Swizzle.webp'),
           ('Mauritian Buck','https://www.crownroyal.ca/dist/images/cr-summer-crown-buck.jpg'),
           ('Mauritian Made', 'https://lets-travel-more.com/wp-content/uploads/2019/12/Green-Tiki-Monk-1.jpg'),
           ('Mauritius Sour', 'https://cdn.shopify.com/s/files/1/1870/8765/files/pappy_co_maple_amaro_sour_rectangle_480x480.jpg?v=1621018089'),
           ("Mayahuel's Revenge",'https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEiht1QZHhliSwHQ6sj6FbFMmcwrrIG3vc-Z1A91egp2dGMR7IhtftC-AN6ZnR_jRFtFhRxfMxfxzHm22hwdbJuEekrkFrNgKksELoQc2eFEyp7XLbK05ivu-hSS-PclAfEh4I1xLdzZj_t8eyYmM1CRX2mSilkLaQrajljJZyVv-qD42GaG3VsGq8I1pg/s320/atlas7427.jpg'),
           ('Mayan Decadence','https://hips.hearstapps.com/amv-prod-gp.s3.amazonaws.com/gearpatrol/wp-content/uploads/2012/12/the-mayan-slide-21.jpg?resize=480:*&keepGifs=1'),
           ('Mayan Mule', 'https://recipe.awesomedrinks.com/media/cocktails/mayan-mule-2.jpg.300x300_q85_crop.jpg'),
           ('Mayan Sacrifice Champagne Cocktail','https://i.pinimg.com/originals/e0/f7/79/e0f77978bdaa2a25770ed8f9d47d00ed.png'),
           ('Mean Martinez', 'https://www.acouplecooks.com/wp-content/uploads/2020/05/Martinez-Cocktail-022.jpg'),
           ('Merry Sherry Cobbler', 'https://sugarandcloth.com/wp-content/uploads/2018/08/Berry-Sherry-Cobbler-Cocktail-Ashley-2.jpg'),
           ('Mexican Sazerac','https://www.patrontequila.com/binaries/largeretina/content/gallery/patrontequila/recipes/patron-silver/the-mexican-sazerac/recipe.jpg'),
           ('Mexico Mule', 'https://cdn.diffords.com/contrib/stock-images/2022/06/62b44a113652b.jpg'),
           ('Mezcal Coffee Old Fashioned', 'https://imbibemagazine.com/wp-content/uploads/2019/03/fishers-mezcal-old-fashioned-crtsy-sawyer-seattle.jpg'),
           ('Mezcal Witch', 'https://www.acouplecooks.com/wp-content/uploads/2021/08/Witchs-Brew-Cocktail-001s-368x368.jpg'),
           ('Milk and honey', 'https://ik.bebodywise.com/mosaic-wellness/image/upload/f_auto,w_1000,c_limit/v1639392008/BW%20BLOG/Untitled-design--32-.jpg'),
           ('Mille Miglia', 'https://destinations.ua/storage/crop/archive-articles/avatar_2038_max.jpg'),
           ('Mint Garden', 'https://www.thevegspace.co.uk/wp-content/uploads/2016/02/english-garden-cocktail-1.jpg'),
           ('Mister Gingy', 'https://www.thevegspace.co.uk/wp-content/uploads/2016/02/english-garden-cocktail-1.jpg'),
           ('Miyagikyo Kick', 'https://musingsonthevine.files.wordpress.com/2013/03/the-brotherhood2.jpg'),
           ('Monet', 'https://cdn.diffords.com/contrib/stock-images/2018/05/5af30c2fd4d31.jpg'),
           ('Morlacco Julep' , 'http://www.completecocktails.com/img/d/l/MorlaccoJulep.jpg'),
           ('Mother Superior', 'https://img.huffingtonpost.com/asset/5d023c432100003711eecb11.jpeg?ops=scalefit_720_noupscale&format=webp'),
           ('Mott and Mulberry', 'https://www.theshakencocktail.com/wp-content/uploads/2022/09/iStock-522978647.jpg'),
           ('Muddled Mission', 'https://www.cocktailsbythebook.com/wp-content/uploads/2016/06/Muddled-Mission-Cocktail.jpg'),
           ('Mule Pigeon','https://d1yfn1dfres2va.cloudfront.net/007/1d/76/1d76c927eac8aad1ae52ffe336fee603_1280m.jpg'),
           ('Mystique Green (Adapted)', 'https://cocktailsoriginaux.files.wordpress.com/2014/11/the-mystic-green-river.jpg?w=418&h=626'),
           ('Napa Vally Sour', 'https://www.saveur.com/uploads/2019/03/18/YOZSWMWSGBV54KV7I2YOMDLO7Q.jpg?auto=webp&auto=webp&optimize=high&quality=70&width=720&dpr=2'),
           ('Nara Mule', 'https://cdn.shopify.com/s/files/1/0259/3036/7042/articles/east-imperial-cocktail-murphys-mule_800x.jpg?v=1658276827'),
           ('Naughty Nikka', 'https://imageio.forbes.com/specials-images/imageserve/5e3b0c94f133f400076bb22b/Passion-at-Ivy-Lane-in-New-York-City-/960x0.jpg?format=jpg&width=960'),
           ('Nectar of the Amazon', 'https://makemeacocktail.com/cdn-cgi/image/f=auto,h=400,sharpen=1,fit=contain/images/cocktails/6881/400_400_amazon.png'),
           ("Negroni D'Amore", 'https://italysegreta.com/wp-content/uploads/2020/10/ergita-sela-pphFzVPHRmo-unsplash-1400x936.jpg'),
           ('Negroni Sorbetto', 'https://www.liqculture.com/wp-content/uploads/2018/06/IMG_9488.jpg'),
           ('Neighborhood Negroni', 'https://www.liquor.com/thmb/ZuRBWnfBA23DpbORAb1ciXiWGAI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/neighborhood-negroni-720x720-primary-727f7dc3a5d04a298d63977679efe856.jpg'),
           ('Neko Colada', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTNCStaZYLlJwGbEkWSAdTeowMH0uRgaigLYw&usqp=CAU'),
           ("Nellie Fer' Toddy", 'https://s.yimg.com/ny/api/res/1.2/B0Io7JzC2fcqk487ukAOlQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTk2MDtjZj13ZWJw/http://magazines.zenfs.com/resizer/2.0/original/v8PYPbtaehGw657jsjiOYewhTWw'),
           ('New Beginnings', 'https://thetastingalliance.com/wp-content/uploads/L1090150-768x1152.jpg'),
           ("Newton's Theory", "https://assets.epicurious.com/photos/5f9852fedda393d6f500ff93/1:1/w_2240,c_limit/One%20Bottle%20Cocktail_Newton's%20Law.jpg"),
           ('Nick & Janae', 'https://cocktailpartyapp.com/wp-content/uploads/Dick-and-Jane.webp'),
           ('Nieux Carré', 'https://assets-prd.punchdrink.com/wp-content/uploads/2021/10/04184712/Article2-Ultimate-Best-Vieux-Carre-Cocktail-Recipe.jpg'),
           ('Nigamono', 'https://cdn.diffords.com/contrib/encyclopedia/2021/05/609e795219b87.jpg'),
           ('Nikka Coffey Grain Perfect Manhattan', 'https://www.liquor.com/thmb/rUh84exb7twmgnJHelnS7ueU6zE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/rob-roy-720x720-primary-e1fe784774a049f49dd534f0596c2d07.jpg'),
           ('Nikka Coffey Malt Old Fashioned', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTHAGI5Kl_Y-pVFeh8M8bYDhblvFjKyuex1CA&usqp=CAU'),
           ('Nikka Earl Grey', 'https://www.cakenknife.com/wp-content/uploads/2018/03/Earl-Grey-Old-Fashioned-Image-4-768x1120.jpg'),
           ("Nikka's Golden Cherry",'https://healthylittlepeach.com/wp-content/uploads/2021/10/shaken-whiskey-cocktail-easy-768x1152.jpg'),
           ('No.3 & T', 'https://www.liquor.com/thmb/nat72xtX_Q8l_n5nK9hTqSorlFU=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/__opt__aboutcom__coeus__resources__content_migration__liquor__2019__09__18090535__Gin-and-Tonic-720x720-recipe-c2e32c4cf53c4ed7a4de20af8e862a12.jpg'),
           ('No.3 Bramble','https://i0.wp.com/www.theeducatedbarfly.com/wp-content/uploads/2020/01/bramble-scaled.jpg?resize=1068%2C601&ssl=1'),
           ('No.3 Negroni', 'https://www.liquor.com/thmb/1YywHOQoudReIUbqmlkw3Cdgdi0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__liquor__2018__05__08110806__negroni-720x720-recipe-7c1b747a616f4659af4008d025ab55df.jpg'),
           ("Nola '75",'https://assets-prd.punchdrink.com/wp-content/uploads/2018/02/Article-Chris-Hannah-Arnauds-New-Orleans-French-75-Recipe.jpg'),
           ('Nori & Islay','https://craftandcocktails.co/wp-content/uploads/2017/06/wolrd-gin-day-17-1.jpg'),
           ('Northern Hemisphere (Nikka 12 Edition)', 'https://blog.cocktailbuilder.com/wp-content/uploads/2016/03/lone-ranger.jpg'),
           ('OH Snap!', 'https://www.winemag.com/wp-content/uploads/2016/04/OhSnap-700x461.jpg'),
           ('Oaxacan Martini', 'https://www.foodandwine.com/thmb/HEclkOU8qscsSnhcu_DKjm_iGcA=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Datu-Datu-Martini-XL-RECIPE1022-2000-237f85d4aeb148f99562255ed2aee11f.jpg'),
           ('Obituary Cocktail', 'https://www.seriouseats.com/thmb/-AIMIcn_f8uJovO7eUL5wkIr4ZQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__serious_eats__seriouseats.com__recipes__images__2015__06__20150622-3-ingredient-cocktail-obituary-cocktail-vicky-wasik-9c5ac8f38dd54a76981d0ca43c948c3d.jpg'),
           ('Ode to Kinshi', 'https://rusticfamilyrecipes.com/wp-content/uploads/2022/11/apple-cider-martini-1.jpg'),
           ('Off the Radar', 'https://assets.bonappetit.com/photos/57adf75b53e63daf11a4e022/1:1/w_2560%2Cc_limit/off-the-radar.jpg'),
           ('Old Pal', 'https://www.liquor.com/thmb/w_tg_lwqrAlQcx-3FvjLEx0IXkI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__liquor__2018__07__18144421__old-pal-720x720-recipe-8f1199df0ff14f8c8abe96689125fa62.jpg'),
           ('Old Tom and The Sea', 'https://www.goodtaste.tv/wp-content/uploads/2017/08/BB_Butcher_2-copy.jpg'),
           ('On the Flipside', 'https://i2.wp.com/dishesdelish.com/wp-content/uploads/2020/07/Cucumber-Mint-Martini-Square-2.jpg'),
           ('On the Fritz', 'https://fritzmueller.fm/uploads/2020/drinks/fritz-mueller-the-earl.jpg'),
           ('On the Wings of Eagles','https://www.liquor.com/thmb/SyFaXZGhvwiP7T0YOzWH46jiqsE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/on-the-wings-of-eagles-720x720-primary-85c6a8098f824fc2b4f7768bc3d76b86.jpg'),
           ('Opaka Raka', 'https://3.bp.blogspot.com/-15XCKMcCT4w/WYpHHMC09eI/AAAAAAAADqk/Zv4j2Z4rzT0mA94182dVotUt1o4U_4WZwCLcBGAs/s320/opakaraka335.jpg'),
           ('Orange Batida','https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTJHYsbyk0z5cOnhplEjd9QdXqulmj_oygrkr5b6Le6ItAPyLCtJXeQhXdSbcu9GPvsAIk&usqp=CAU'),
           ('Orchard Malt Mule', 'https://www.grasovka.de/wp-content/uploads/grapplesovka-768x768.jpg'),
           ('P.T. Barnum Cocktail','https://mixthatdrink.com/wp-content/uploads/2011/02/barnum-cocktail-600x600.jpg'),
           ('PB&K Old Fashioned','https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRY-i2P6dutzN8egf3S2ytW2MX2FqwVILdOtw&usqp=CAU'),
           ('PDA','https://zestfulkitchen.com/wp-content/uploads/2018/10/Bourbon-apple-smash-from-Lauren-Grant-of-Zestful-Kitchen-7-of-8_1-scaled.jpg'),
           ('Pacific Breeze', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmPvD2Q6_2uZ5IqysYbwfuYwTjoC9o2CRqoJCKhzaQ_d7AzenGkttvul94oDe6I1WgCI8&usqp=CAU'),
           ('Pacific Kick', 'https://www.liquor.com/thmb/01x9xeiRWC00AhyF30qZCK5TY0k=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/across-the-pacific--720x720-primary-002110f009c44fc3b0b45fbb3d7908ad.jpg'),
           ('Padova Collins', 'http://www.completecocktails.com/img/d/l/PaduaCollins.jpg'),
           ('Palais Royal','https://www.haveacocktail.com/images/da/5/5811.jpg'),
           ('Palermo Breeze','https://storage.googleapis.com/gen-atmedia/3/2014/09/eed78b8968d180846ef148d6be74504ff9ed5c75.jpeg'),
           ('Pants off Dance off', 'https://mlxba11sslu7.i.optimole.com/w:auto/h:auto/q:mauto/f:avif/https://millstreambrewing.com/wp-content/uploads/2022/03/Pants-Off-Glass.jpeg'),
           ('Paradiso Sun','https://static.emerils.com/styles/wmax-600-sq/public/IMG_2948_0.JPG?itok=vtZMSnjw'),
           ('Passionate Pigeon', 'https://www.pikpng.com/pngl/m/296-2965981_free-png-cocktail-png-images-transparent-passion-fruit.png'),
           ('Peace Daiquiri', 'https://i2.wp.com/dishesdelish.com/wp-content/uploads/2020/06/Bing-Cherry-Cosmo-Square-1.jpg'),
           ('Peach Batida', 'https://www.lecremedelacrumb.com/wp-content/uploads/2019/07/peaches-n-cream-moon-milk-1-500x500.jpg'),
           ('Peachy Keane', 'https://cdn.shopify.com/s/files/1/1216/2612/files/A_dehydrated_slice_of_orange_in_a_cocktail_glass.jpg?v=1632313658'),
           ('Pear and Cranberry Fizz','https://i.pinimg.com/originals/9e/54/02/9e5402e9124b590983677d2921b7af04.png'),
           ('Peruvian Wish (Adapted)','http://www.completecocktails.com/img/d/l/PeruvianWish.jpg'),
           ('Peter Pumpkin','https://imbibemagazine.com/wp-content/uploads/2014/10/Peter-2BPeter-2BPumpkin-2BEater-2BThe-2BSkylark.jpg'),
           ('Phad Thai','https://advancelocal-adapter-image-uploads.s3.amazonaws.com/image.lehighvalleylive.com/home/lvlive-media/width2048/img/food_impact/photo/thai-tea-martini-10a8a2d750dea77a.jpg'),
           ('Phineas Flip','https://www.liquor.com/thmb/Px3KvXCEyO8pcBWF25kji1-n3do=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/porto-flip-720x720-primary-1cd2de9da74648889edb1bdeea49e1a5.jpg'),
           ('Picadilly','https://www.haveacocktail.com/images/da/6/6011.jpg'),
           ('Piedra de sol','https://www.tsaknakisbros.gr/wp-content/uploads/2015/04/71piedra-del-sol.jpg'),
           ('Pina Del Este','https://i0.wp.com/midnightmixologist.com/wp-content/uploads/2017/08/a_Hawaiian_Stone_Sour.jpg?fit=600%2C554&ssl=1'),
           ('Pineapple Express','https://cdn.diffords.com/contrib/stock-images/2021/10/6169389acaddd.jpg'),
           ('Pink & Black','https://gardenandgun.com/wp-content/uploads/2014/07/GG0414_Drinks_01.jpg'),
           ('Pink & Ginger','https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFgHRp2rV3_kdxUzvZqcjyj_SKPSu2SxeXjQ&usqp=CAU'),
           ('Pink Colada','https://tipsybartender.com/wp-content/uploads/2018/01/Strawberry-Pina-Colada-2.jpg?fit=crop&ar=1:1'),
           ('Pink Mojito','https://www.supergoldenbakes.com/wordpress/wp-content/uploads/2015/03/Pink_mojito_4.png'),
           ('Pink Pigeon Punch','https://i.pinimg.com/736x/21/c4/0a/21c40ab14d4f1da41c4ef601fb86a207--pink-punch-fruit-punch.jpg'),
           ('Pink Punch', 'https://lilluna.com/wp-content/uploads/2013/08/lemonade-soda-resize-2.jpg'),
           ('Pink Ribbon', 'https://weddingsbythebreakers.com/wp-content/uploads/2015/09/HMF_PinkRibbonMartini_700.jpg'),
           ('Pisco Punch', 'https://images.squarespace-cdn.com/content/v1/597eb9bf86e6c03d802291e8/1598335364486-48SN89A1UL8BCN90KIA1/Pisco+Punch?format=1000w'),
           ('Pisco Punch (Adaptation by The Commissary)', 'https://images.squarespace-cdn.com/content/v1/5bafc73934c4e20db5636a22/1634432229851-X6O8KWZ3NX268OU717OH/piscopunch.jpg'),
           ('Pisco Punch (Adaptation by The Comstock Saloon)', 'https://imbibemagazine.com/wp-content/uploads/2013/07/pisco-punch-presidio-horiz-crdt-emma-janze.jpg'),
           ('Pistachio Follies', 'https://madtini.com/wp-content/uploads/2011/02/madtini_valentines_chocolate_swirl_martini.jpg'),
           ('Platonic Snuggle','https://s.hdnux.com/photos/07/11/55/1874775/8/1200x0.jpg'),
           ('Playa Matalan (Mezcal Negroni)', 'https://www.liquor.com/thmb/KPTRXSVO7vyx7O2fPyNkLh9JQPo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/mezcal-negroni-1500x1500-primary-6f6c472050a949c8a55aa07e1b5a2d1b.jpg'),
           ('Polish Penance', 'https://cdn.diffords.com/contrib/stock-images/2018/05/5af30fef94ff0.jpg'),
           ('Pontchartrain Punch','https://i.pinimg.com/originals/29/da/3e/29da3ea1fd3148d66b0b9510c5c0fba6.png'),
           ('Prata Punch', 'https://munchies-images.vice.com/wp_upload/prata-punch.jpg?crop=1xw:0.84375xh;center,center&resize=1000:*'),
           ('Prickly Pear Margarita', 'https://www.acouplecooks.com/wp-content/uploads/2021/04/Prickly-Pear-Margarita-004s.jpg'),
           ('Primo Carnera', 'https://i1.wp.com/robertosbar.com/wp-content/uploads/2018/12/01_americano.jpg?fit=1576%2C2245&ssl=1'),
           ('Prince of Humbugs','https://www.atipsygiraffe.com/wp-content/uploads/2017/09/prince-that-was-promised-game-of-thrones-cocktail-9-aquare.jpg'),
           ('Profundo', 'http://www.completecocktails.com/img/d/l/Profundo.jpg'),
           ('Pumpkin & Pecan', 'https://www.acouplecooks.com/wp-content/uploads/2021/08/Pumpkin-Cocktail-Pumpkin-Old-Fashioned-012.jpg'),
           ('Pumpkin and Spice', 'https://www.thefitpeach.com/wp-content/uploads/2021/10/Cozy-Maple-Pumpkin-Bourbon-Cocktail-with-Apple-Cider-9.jpg'),
           ('Radice Amara', 'https://cheersonline.com/wp-content/uploads/2023/04/Carrots-Rabbits-Diamonds-500x500.png'),
           ('Raspberry Batida', 'https://4.bp.blogspot.com/-92o_G9g2024/UAIQ4D1igPI/AAAAAAAAJAU/RmENvQIul98/s1600/2+IMG_4305.JPG'),
           ('Red Bud Trail' ,'https://d33wubrfki0l68.cloudfront.net/5b14fe654a5425d05e7de5461eb3c61d8dd315f9/ef21c/images/uploads/2019_06_09_redbud_sour_5.jpg'),
           ('Red Letters', 'https://cheersonline.com/wp-content/uploads/2020/02/Buy-Me-Flowers.jpeg'),
           ('Redondo Beach', 'https://cdn.diffords.com/contrib/stock-images/2018/05/5af31203365f4.jpg'),
           ('Rhapsody in Red', 'https://rhapsodybar.files.wordpress.com/2021/04/rhapsody-website-photos-2.png?w=1024'),
           ('Rio De Janeiro Mule', 'https://www.baconismagic.ca/wp-content/uploads/2016/06/moscow-mule-h2.jpg'),
           ("Rita's Song",'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR0izQesbuaRoHHES6r6P5Y3MhZqA6nhpsaUqjw2bplxGDCd-buvs0-DMKTVhKeiMTeq7w&usqp=CAU'),
           ('Ritz Cocktail', 'https://cdn.diffords.com/contrib/stock-images/2017/1/58/2017c85dac64f4c4755a02d94dec2cd5a0d2.jpg'),
           ('Roasted Cherry Colada', 'https://www.saveur.com/uploads/2019/03/18/QBJUPSOKGT3JTWMGYHV6TQCDQA.jpg?auto=webp&width=2000&height=1500'),
           ('Root Down', 'https://edibleindy.ediblecommunities.com/sites/default/files/styles/recipe_banner/public/images/recipe/rootdown3.jpg?itok=kntMWtHH&c=bdf77c4a5615598ac7f9bc3c4a3e8739'),
           ('Rose Sangria', 'https://www.acouplecooks.com/wp-content/uploads/2020/06/Rose-Sangria-011.jpg'),
           ('Rothes Julep', 'https://pbs.twimg.com/media/Do0x5IqX0AAZCYq.jpg'),
           ('Rothes Roy', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTA66OD-ch9-yGItjTNuGIHQITdx4A5xrUh8GIxrS1kdgy_kal4NCzP9ROmCCZogu1fZF4&usqp=CAU'),
           ('Round Pond Aperitif', 'https://img.texasmonthly.com/2015/09/tipsy-texan-cocktail-of-month-david-alan-pimms-cup-the-monterey-san-antonio.jpg?auto=compress&crop=faces&fit=crop&fm=jpg&h=1050&ixlib=php-3.3.1&q=45&w=1400'),
           ("Rudolph's Rose", 'https://lizkellybooks.com/wp-content/uploads/2020/12/rudolphsrevenge_small.jpg'),
           ('Rx Hot Toddy', 'https://cookieandkate.com/images/2017/12/classic-hot-toddy-recipe-2.jpg'),
           ('SOMA Fizz', 'https://data.thefeedfeed.com/recommended/post_3836791.jpeg'),
           ('Sabotage', 'https://us.inshaker.com/uploads/cocktail/promo/733/1542205428-Sabotage-_promo.jpg'),
           ("Sade's Taboo", 'https://static.wixstatic.com/media/1f0c0a_e4de7e9176594ecfbb68274581fa4dc3~mv2.jpg/v1/fill/w_640,h_738,al_c,q_85,usm_0.66_1.00_0.01,enc_auto/1f0c0a_e4de7e9176594ecfbb68274581fa4dc3~mv2.jpg'),
           ('Sage & Sound', 'https://inspiredbycharm.com/wp-content/uploads/2021/08/Bourbon-and-Sage-Cocktail.jpg'),
           ('Sahara Glowing Heart', 'https://makemeacocktail.com/cdn-cgi/image/f=auto,h=400,sharpen=1,fit=contain/images/cocktails/5489/400_267_saharaglowingheart.jpg'),
           ('Salty Swede', 'https://images.absolutdrinks.com/drink-images/Raw/Absolut/aab5c796-3cd5-4761-b378-3064b95cf529.jpg'),
           ('San Fran Shandy', 'https://www.spoonforkbacon.com/wp-content/uploads/2020/07/summer-shandy-cocktail-800x1065.jpg'),
           ('San Fran Soda', 'https://cdn.diffords.com/contrib/stock-images/2017/1/35/20177a4afa2805cadc76ed770d94796fa124.jpg'),
           ('San Francisco Harvest', 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTn2cFvKOL-UUJCyEujGTpNeb8oU8DPyEqKVAwmTnggHjcOE-y5RwRciPcLN3_XEKEsX9Y&usqp=CAU'),
           ('San Francisco Strong (Skrong)', 'https://sipsfromscripts.com/wp-content/uploads/2021/10/San-Francisco-Cocktail-Recipe-SipsFromScripts.webp'),
           ('Santa Patricia', 'https://vinepair.com/wp-content/uploads/2021/07/cocktailroundup_tequilasunrise_internal.jpg'),
           ('Scotch Joplin', 'https://i0.wp.com/club609.com/wp-content/uploads/2019/10/Screen-Shot-2019-10-30-at-3.28.10-PM.png?fit=889%2C590&ssl=1'),
           ('Second City Sour', 'https://www.2foodtrippers.com/wp-content/uploads/2022/05/New-York-Sour-Cocktail-with-Black-Background-Centered-1024x858.jpg'),
           ("See You T'Amaro",'https://www.gastronomblog.com/wp-content/uploads/2016/04/ttsour-4.jpg.webp'),
           ('See ya Amaro!', 'https://cdn.diffords.com/contrib/stock-images/2023/03/64133ce097fac.jpg'),
           ('Seersucker Sunshine', 'https://toriavey.com/images/2013/05/Orange-Blossom-Margarita.jpg'),
           ('Shadowcat', 'https://www.acouplecooks.com/wp-content/uploads/2020/04/Vodka-Tonic-001.jpg'),
           ('Shaken drake', 'https://drakesorganic.com/wp-content/uploads/2021/07/hero-image-1.png'),
           ('Short Round', 'https://www.mysequinedlife.com/wp-content/uploads/2015/11/frozen-gold-rush-cocktail-11.jpg'),
           ('Short Round II', 'https://s3-media0.fl.yelpcdn.com/bphoto/wc8Ep9ALJtROgOShcwEJ2w/1000s.jpg'),
           ('Shroud of the Inca', 'https://www.journeymachupicchu.com/wp-content/uploads/2021/02/The-Machu-Picchu-in-a-Glass.jpg'),
           ('Nuestra Julep', 'https://www.winemag.com/wp-content/uploads/2017/05/Mint-Julep-700x461.jpeg'),
           ('Parisian Manhattan', 'https://cdn.diffords.com/contrib/stock-images/2020/07/5f06fc00e201d.jpg'),
           ('Party in the Agave Fields', 'https://www.peelwithzeal.com/wp-content/uploads/2020/04/healthy-mezcal-paloma-cocktail-recipe.jpg'),
           ('Passion Fruit Batida', 'https://braziliankitchenabroad.com/wp-content/uploads/2022/02/Batida-de-Maracuja-Passion-fruit-cocktail-with-vodka-13-480x270.jpg'),
           ('Sidewinder','https://www.firstpourcocktails.com/wp-content/uploads/2022/07/Sidewinders-Fang-Cocktail.jpg')
           
           
          ]
    for name, link in lst:
        data.loc[data['drink_name'] == name, 'picture'] = link
    
    return data

# %%
data = add_picture_links(data)
data
# Out:
#                                     drink_name  \
# 0                                #106 Cocktail
# 1         '57 Chevy with a White License Plate
# 2                               1-900-FUK-MEUP
# 3                                      10 to 7
# 4                             110 in the shade
# ...                                        ...
# 1712                                    Zoksel
# 1713                                    Zombie
# 1714                                 Zorbatini
# 1715                                     Zorro
# 1716  “Prepare for Destiny! Where’s my Pizza?”
#
#                                            instructions  steps  \
# 0     Shake and double strain into a coupe. Garnish ...      4
# 1     1. Fill a rocks glass with ice 2.add white cre...      3
# 2     Shake ingredients in a mixing tin filled with ...      2
# 3     Shake and serve up in a martini glass with lem...      1
# 4                 Drop shooter in glass. Fill with beer      1
# ...

# %% [markdown]
# ### Adding Tags

# %%
#Drinks to find tags for
data[pd.isna(data['tags'])]['drink_name'][293:]
# Out:
# 1150                                Peach Batida
# 1152                                Peachy Keane
# 1154                     Pear and Cranberry Fizz
# 1158                     Peruvian Wish (Adapted)
# 1159                               Peter Pumpkin
#                           ...
# 1697                            You Go Glen Coco
# 1698                     You're Bitter Than That
# 1699                          Ypioca Chile Punch
# 1700                          Ypioca Yellow Card
# 1716    “Prepare for Destiny! Where’s my Pizza?”
# Name: drink_name, Length: 231, dtype: object

# %%
def add_tag_links(data):
    
    lst = [('#106 Cocktail', 'cocktail white'),
           ('10 to 7', 'martini yellow'),
           ("1880's Americana", 'short orange'),
           ("20th Century", 'yellow citrus'),
           ('3 & Tree', 'brown short'),
           ('3 Degrees', 'yellow cocktail citrus'),
           ('3AM', 'clear citrus longdrink'),
           ('50/50 Split', 'martini citrus clear'),
           ('7th Heaven', 'cocktail white citrus'),
           ('Mandrake', 'cocktail red strong'),
           ('Mango No. 3', 'yellow sweet cocktail'),
           ('Maraschino Side Car', 'sweet sidecar punch orange'),
           ('Marchesa' , 'berry red short'),
           ('Maria Canevari Punch', 'floral light clear cocktail'),
           ("Masataka's Vision",'nutty rich clear cocktail short'),
           ('Mauritian Buck', 'whiskey short bitter yellow'),
           ('Mauritian Made', 'mint rum citrus cocktail'),
           ('Mauritius Sour', 'short sour citrus'),
           ("Mayahuel's Revenge",'smoky coupe glass orange'),
           ('Mayan Decadence', 'short orange bitters'),
           ('Mayan Mule', 'classic cocktail copper mug citrus smokey'),
           ('Mayan Sacrifice Champagne Cocktail', 'fruity citrus classic cocktail anise clear'),
           ('Mean Martinez', 'gin strong classic cocktail orange'),
           ('Merry Sherry Cobbler', 'sweet citrus fresh longdrink orange'),
           ('Mexican Sazerac', 'strong short clears smokey absinthe'),
           ('Mexican Mule', 'classic cocktail copper mug fresh citrus clear'),
           ('Mezcal Coffee Old Fashioned', 'smokey bitter strong brown'),
           ('Mezcal Witch', 'green short smokey'),
           ('Mille Miglia', 'classic cocktail cherry citrus fresh red'),
           ('Mint Garden', 'minty fresh green yellow'),
           ('Mexico Mule', 'long clear minty fresh'),
           ('Mister Gingy', 'bitter fresh green yellow'),
           ('Miyagikyo Kick', 'red citrus strong classic cocktail'),
           ('Monet','classic cocktail red citrus smooth'),
           ('Morlacco Julep', 'mint cherry clear short fruity fresh' ),
           ('Mother Superior', 'bitter fruity citrus yellow'),
           ('Mott and Mulberry', 'short fruity orange'),
           ('Muddled Mission', 'red classic cocktail berry sweet bitter citrus'),
           ('Mystique Green (Adapted)', 'tangy citrus fresh fruity classic cocktail green'),
           ('Mule Pigeon', 'clear short bitter strong'),
           ('Nara Mule', 'fresh citrus highball glass orange'),
           ('Naughty Nikka', 'long orange bitter fresh classic cocktacil'),
           ('Nectar of the Amazon', 'yellow fresh long classic cocktail nutty sweet'),
           ("Negroni D'Amore",'red strong short bitter'),
           ('Negroni Sorbetto', 'red strong short bitter'),
           ('Neighborhood Negroni', 'red short bitter'),
           ('Neko Colada', 'classic cocktail creamy citrus yellow'),
           ("Nellie Fer' Toddy",'orange short bitter strong nutty'),
           ('New Beginnings', 'classic cocktail nutty yellow strong'),
           ("Newton's Theory",'smooth short fruity strong bitter'),
           ('Nick & Janae', 'bitter citrus red long classic cocktail'),
           ('Nieux Carré' ,'short yellow bitter'),
           ('Nigamono', 'bitter brown short'),
           ('Nikka Coffey Grain Perfect Manhattan', 'bitter brown classic cocktail'),
           ('Nikka Coffey Malt Old Fashioned', 'bitter brown short strong'),
           ('Nikka Earl Grey', 'smokey short sweet brown orange'),
           ("Nikka's Golden Cherry", 'yellow short bitter dry citrus'),
           ('No.3 & T', 'clear highball glass long citrus'),
           ('No.3 Bramble','citrus berry bitter purple short'),
           ('No.3 Negroni',"dark red bitter short citrus"),
           ("Nola '75",'sparkling fresh citrus berry orange classic cocktail'),
           ('Nori & Islay','clear long classic cocktail bitter seaweed'),
           ("Northern Hemisphere (Nikka 12 Edition)",'pink strong citrus sweet classic cocktail'),
           ('Nuestra Julep','bitter fruity clear classic cocktail copper mug'),
           ('OH Snap!','sweet green classic cocktail citrus fresh'),
           ('Oaxacan Martini',''),
           ('Obituary Cocktail', ''),
           ('Ode to Kinshi', ''),
           ('Off the Radar', ''),
           ('Old Tom and The Sea', ''),
           ('On the Flipside', ''),
           ('On the Fritz', ''),
           ('On the Wings of Eagles', ''),
           ('Opaka Raka', ''),
           ('Orange Batida', ''),
           ('Orchard Malt Mule', ''),
           ('P.T. Barnum Cocktail', ''),
           ('PB&K Old Fashioned', ''),
           ('PDA', ''),
           ('Pacific Breeze', ''),
           ('Pacific Kick', ''),
           ('Padova Collins', ''),
           ('Palais Royal',''),
           ('Palermo Breeze', ''),
           ('Pants off Dance off', ''),
           ('Paradiso Sun', ''),
           ('Parisian Manhattan', ''),
           ('Party in the Agave Fields', ''),
           ('Passion Fruit Batida', ''),
           ('Passionate Pigeon', ''),
           ('Peace Daiquiri', ''),
           ('Peach Batida', ''),
           ('Peachy Keane', ''),
           ('Pear and Cranberry Fizz', ''),
           ('Peruvian Wish (Adapted)', ''),
           ('Peter Pumpkin', ''),
           
           
          ]
    for name, tags in lst:
        data.loc[data['drink_name'] == name, 'tags'] = tags
    return data

# %%
data = add_tag_links(data)
data
# Out:
#                                     drink_name  \
# 0                                #106 Cocktail
# 1         '57 Chevy with a White License Plate
# 2                               1-900-FUK-MEUP
# 3                                      10 to 7
# 4                             110 in the shade
# ...                                        ...
# 1712                                    Zoksel
# 1713                                    Zombie
# 1714                                 Zorbatini
# 1715                                     Zorro
# 1716  “Prepare for Destiny! Where’s my Pizza?”
#
#                                            instructions  steps  \
# 0     Shake and double strain into a coupe. Garnish ...      4
# 1     1. Fill a rocks glass with ice 2.add white cre...      3
# 2     Shake ingredients in a mixing tin filled with ...      2
# 3     Shake and serve up in a martini glass with lem...      1
# 4                 Drop shooter in glass. Fill with beer      1
# ...

# %%
data.to_csv('tags.csv')
