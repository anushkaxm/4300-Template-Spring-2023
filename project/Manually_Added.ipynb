# %%
import pandas as pd
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
#pd.options.display.max_colwidth = 200

# %%
data = pd.read_csv('tags.csv')
data = data.drop(columns = {'id'})
data
# Out:
#                                     drink_name  \
# 0                                #106 Cocktail
# 1         '57 Chevy with a White License Plate
# 2                               1-900-FUK-MEUP
# 3                                      10 to 7
# 4                             110 in the shade
# ...                                        ...
# 1712                                    Zoksel
# 1713                                    Zombie
# 1714                                 Zorbatini
# 1715                                     Zorro
# 1716  “Prepare for Destiny! Where’s my Pizza?”
#
#                                            instructions  steps  \
# 0     Shake and double strain into a coupe. Garnish ...      4
# 1     1. Fill a rocks glass with ice 2.add white cre...      3
# 2     Shake ingredients in a mixing tin filled with ...      2
# 3     Shake and serve up in a martini glass with lem...      1
# 4                 Drop shooter in glass. Fill with beer      1
# ...

# %% [markdown]
# ### Adding Picture Links

# %%
#Drinks to find pictures for
data[pd.isna(data['picture'])]['drink_name']
# Out:
# 546           Down the Rabbit Hole
# 549                  Drink Lab #16
# 551               Drops of Jupiter
# 553             Dry Mauritian Sour
# 558     Duke's Classic Dry Martini
#                    ...
# 1340                  Shaken drake
# 1347                   Short Round
# 1348                Short Round II
# 1351            Shroud of the Inca
# 1354                    Sidewinder
# Name: drink_name, Length: 315, dtype: object

# %%
#Drinks to find pictures for
data[pd.isna(data['picture'])]
# Out:
#                       drink_name  \
# 546         Down the Rabbit Hole
# 549                Drink Lab #16
# 551             Drops of Jupiter
# 553           Dry Mauritian Sour
# 558   Duke's Classic Dry Martini
# ...                          ...
# 1340                Shaken drake
# 1347                 Short Round
# 1348              Short Round II
# 1351          Shroud of the Inca
# 1354                  Sidewinder
#
#                                            instructions  steps picture   tags  \
# 546   Add all ingredients into a shaker, shake strai...      1     NaN    NaN
# 549                 Shake, strain, lemon twist garnish.      1     NaN    NaN
# 551   Combine all ingredients except Duke's Lemon ga...      3     NaN    NaN
# 553   Dry shake, shake with cubed ice, double strain...      1     NaN    NaN
# 558   Pour the Extra Dry Vermouth into a frozen mart...      7     NaN    NaN
# ...                                                 ...    ...     ...    ...
# ...

# %%
data[data['drink_name'] == 'Bloody Swede']
# Out:
#        drink_name                                       instructions  steps  \
# 283  Bloody Swede  Combine all ingredients in a large pitcher and...      2
#
#                                                picture           tags  \
# 283  https://img.delicious.com.au/yXt0MINq/w759-h50...  red longdrink
#
#               ingredients1 quantity1 ingredients2 quantity2 ingredients3  \
# 283  karlsson's gold vodka      2 oz   bloody mix      2 oz  caper berry
#
#     quantity3  ingredients4 quantity4   ingredients5 quantity5 ingredients6  \
# 283         1  celery stalk         1  cherry tomato         1           ni
#
#         quantity6 ingredients7 quantity7 ingredients8 quantity8  \
# 283  1  pepperonc     led okra    1  pic   tail onion    1  coc
#
#         ingredients9 quantity9 ingredients10     quantity10  \
# 283  pipparas pepper         1           NaN  1  lemon slic
#
#               ingredients11 quantity11 ingredients12 quantity12
# ...

# %%
def add_picture_links(data):
    lst = [('Apple Banana Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_apple_banana_smoothie-1.png'),
           ('Avo-Banana Kale Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_avo_banana_kale-1.png'),
           ('Avocado Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_avocado_smoothie-1.png'),
           ('Banana Blackberry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_banana_blackberry_smoothie-1.png'),
           ('Banana-Ginger Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_banana_ginger-1.png'), 
           ('Basil Strawberry Mango Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_basil_strawberry_mango_smoothie-1.png'),
           ('Berry Berry Blast Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_berry_blast-1.png'),
           ('Black Raspberry-Vanilla Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_black_raspberry_vanilla-1.png'),
           ('Blackberry and Peach Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_blackberry_and_peach_smoothie-1.png'),
           ('Cantaloupe Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_cantaloupe_smoothie-1.png'),
           ('Cherry Banana Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_cherry_banana_smoothie-1.png'),
           ('Cinnapear Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_cinnapear_smoothie-1.png'),
           ('Collard Greens Smoothie with Mango &', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_collard_greens_mango_lime-1.png'),
           ('Creamsicle Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_creamsicle_smoothie-1.png'),
           ('Frozen Blueberry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_frozen_blueberry_smoothie-1.png'),
           ('Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_fruit_smoothie-1.png'),
           ('Fruity Spinach Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_fruity_spinach_smoothie-1.png'),
           ('Ginger Winter Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_ginger_winter_green_smoothie-1.png'),
           ('Gloomy Day Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_gloomy_day_smoothie-1.png'),
           ('Green Envy Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_envy_avocado-1.png'),
           ('Green Julius Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_julius_smoothie-1.png'),
           ('Green Slime Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_slime_smoothie-1.png'),
           ('Green Tea and Honey Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_tea_smoothie-1.png'),
           ('Green Tropics Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_green_tropics_smoothie-1.png'),
           ('Healthy Green Coconut Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_healthy_green_coconut_smoothie-1.png'),
           ('Healthy Winter Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_healthy_winter_smoothie-1.png'),
           ('Heart Healthy Oat & Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_heart_healthy_oat_and_fruit_smoothie-1.png'),
           ('Honeydew-Almond Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_honeydew_almond-1.png'),
           ('Kale Ginger Detox Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_kale_ginger_detox-1.png'),
           ('Kiwi Berry Punch Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_kiwi_berry_punch-1.png'),
           ('Lean Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_lean_green_smoothie-1.png'),
           ('Mango and Yogurt Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_mango_and_yogurt_smoothie-1.png'),
           ('Mixed Berry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_mixed_berry_smoothie-1.png'),
           ('Nectarine Sunshine Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_nectarine_sunshine_smoothie-1.png'),
           ('Oatmeal & Strawberry Breakfast Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_oatmeal_strawberry-1.png'),
           ('Papaya Surprise Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_papaya_surprise_smoothie-1.png'),
           ('Peach & Coconut Dream Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_peach_coconut_dream_green-1.png'),
           ('Pomegranate Breakfast Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_pomegranate_breakfast_smoothie-1.png'),
           ('Pumpkin Pie Fall Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_pumpkin_pie_fall_smoothie-1.png'),
           ('Purple Cow Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_purple_cow_smoothie-1.png'),
           ('Rainforest Fusion Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_rain_forest_fusion-1.png'),
           ('Raspberry & Banana Smoothie with Flax', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_raspberry_banana_flax-1.png'),
           ('Raspberry Good Peach Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_berry_good_peach-1.png'),
           ('Red, White and Blue Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_red_white_blue_smoothie-1.png'),
           ('Sour Black Cherry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_sour_black_cherry_smoothie-1.png'),
           ('Spa Cucumber Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_spa_cucumber_smoothie-1.png'),
           ('Spinach Smoothie with Avocado & Apple', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_spinach_smoothie_with_avocado_and_apple-1.png'),
           ('Spinach, Grape and Coconut Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_spinach__grape_and_coconut_smoothie-1.png'),
           ('Strawberry Coconut Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_coconut_smoothie-1.png'),
           ('Strawberry Mango Spring Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_mango_spring_smoothie-1.png'),
           ('Strawberry Peach Carrot Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_peach_carrot_smoothie-1.png'),
           ('Strawberry-Kiwi Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_strawberry_kiwi-1.png'),
           ('Summer Stone Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_summer_stone_fruit_smoothie-1.png'),
           ('Sunshine in a Glass Green Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_sunshine_ina_jar-1.png'),
           ('Sweet Veggie Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_sweet_veggie_smoothie-1.png'),
           ('Tropical Blueberry Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_tropical_blueberry_smoothie-1.png'),
           ('Winter Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_winter_smoothie-1.png'),
           ('Yogurt Fruit Smoothie', 'https://images.cocktailflow.com/v1/cocktail/w_300,h_540/cocktail_yogurt_fruit_smoothie-1.png'),
           ('#106 Cocktail', 'https://talesofthecocktail.org/wp-content/uploads/2016/11/106cocktail.jpg'),
           ('10 to 7', 'https://www.inspiredtaste.net/wp-content/uploads/2010/07/Lemon-Drop-Martini-Cocktail-Recipe-2-1200.jpg'),
           ("1880's Americana", 'https://www.thespruceeats.com/thmb/ztnL3iwFJ09ut-XAPAhvFgTsgP8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/old-fashioned-cocktail-recipe-and-history-759328-hero-01-c9002b3aa6d24a3781befa19dc69eb0e.jpg'),
           ('20th Century', 'https://imbibemagazine.com/wp-content/uploads/2019/02/anatomy-20th-century-cocktail-crdt-john-valls-dk.jpg'),
           ('3 & Tree', 'https://mscwordpresscontent.s3.amazonaws.com/wa/wp-content/uploads/2021/07/three-trees.jpg?resize=1920x0'),
           ('3 Degrees', 'https://burrataandbubbles.com/wp-content/uploads/2020/11/pear-sage-gimlet.jpg'),
           ('3AM', 'https://www.shot-cocktail-recipe.com/data/img/glass/3.jpg'),
           ('50/50 Split', 'https://www.liquor.com/thmb/loLyerdf2WBrNUZ6d7_jtJdpwIQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/50-50-martini-1500x1500-hero-e56870ded762483da2406176979cb452.jpg'),
           ('7th Heaven', 'https://www.cupofzest.com/wp-content/uploads/2016/09/Seventh-Heaven-Cocktail-THUMBNAIL.jpg'),
           ('A Bloody Shame', 'https://i.guim.co.uk/img/media/11871c31e36a68b2899860c15ab088baa2f3a51a/0_775_3211_1926/master/3211.jpg?width=620&quality=45&dpr=2&s=none'),
           ('A Botanical Garden', 'https://i2.wp.com/girlandtonic.co/wp-content/uploads/2020/05/NG1.jpg?w=1482&ssl=1'),
           ('A Gift from Zara', 'https://i0.wp.com/emilylaurae.com/wp-content/uploads/2022/07/white-negroni.jpg?w=1200&ssl=1'),
           ('A Love Song', 'https://www.7x7.com/media-library/eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpbWFnZSI6Imh0dHBzOi8vYXNzZXRzLnJibC5tcy81NDk3MzM4LzEyMDB4NjAwLnBuZyIsImV4cGlyZXNfYXQiOjE3MTYyNzc0OTF9.9eVuUPWra-dD9TVvkIjcDrXlRlROyFCUopVmwoR4NXM/image.png?width=980&quality=85'),
           ('A Mi Manera (My Way) Pisco Punch', 'https://cdn.shopify.com/s/files/1/0583/3185/products/PiscoPunch_800x.jpg?v=1611331361'),
           ('A Regal Air', 'https://www.liquor.com/thmb/ZN2YdB39slEYrrB8fSzYgCVz1Ck=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/__opt__aboutcom__coeus__resources__content_migration__liquor__2018__09__24201117__clairin-regal-sour-720x720-recipe-8440f3c002614148b787cc469074b1bf.jpg'),
           ('A Southern Jackass', 'https://www.easy-cocktail-recipes.net/v2/webp/721350-PRT5CV-880-300x300.webp'),
           ('A Tall Tell', 'https://dmc.dilmahtea.com/web-space/dmc/recipes/904f2cc1c3677bb35876e91f4716341c06769cc6/500_500.145948250099976.jpg'),
           ('A.Nise', 'https://drinkstraightup.files.wordpress.com/2013/12/a-nise-one-6.jpg?w=984&h=1476'),
           ('Abano Sour', 'https://cdn.shopify.com/s/files/1/0843/4491/articles/1522261274813_0133ec0d-f6bd-42c9-9e89-18a133d2b048_720x.jpeg?v=1559976351'),
           ('Above My Pay Grade', 'https://hips.hearstapps.com/toc.h-cdn.co/assets/17/05/scotlandaberfeldygoldendram.jpg?crop=0.9986921266021449xw:1xh;center,top&resize=980:*'),
           ('Abrazo Latino', 'https://familiakitchen.com/wp-content/uploads/2021/04/Cinco-de-Mayo-concept-2.jpg'),
           ('Across The Pond', 'https://media-cdn.tripadvisor.com/media/photo-s/1d/75/9b/2a/across-the-pond-cocktail.jpg'),
           ('Adriatique', 'https://www.saveur.com/uploads/2019/02/08/ERLNPJXMG3MT7N3IOG45B4MILI.jpg?auto=webp&auto=webp&optimize=high&quality=70&width=450&dpr=2'),
           ('Almond Brother', 'https://cocktailpartyapp.com/wp-content/uploads/Almond-Brother.webp'),
           ('Almond Crusta', 'https://bombay.rocks/wp-content/uploads/2018/10/almond-crusta-_-credit_-bestia.jpg'),
           ('Amaretto Bourbon Punch', 'https://www.howsweeteats.com/wp-content/uploads/2016/04/amaretto-bourbon-punch-I-howsweeteats.com-1.jpg'),
           ('Amaretto Jello Shot, Why Not', 'https://lh3.googleusercontent.com/vHANsWLzZWjZT3DPh1ZcGiGnM7zMBixT26VWbKIIeTqZa6TFRuQ5kR6brlBxRlsoDWjUn_sa3y5SY7uQsJ1U4sIqc1y98Et5WA=w1707-h1707-c-rj-v1-e365'),
           ('Amaretto Sour (Modern)', 'https://www.bakingbeauty.net/wp-content/uploads/2020/02/amaretto-sour-2-768x1152.jpg'),
           ('Amaretto Sour BV-Style', 'https://www.liquor.com/thmb/JceajTbuEnqnNSYKzpcOM0ufaKY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__liquor__2017__11__06162314__amaretto-sour-720x720-recipe-89a34cc23d294def8602ae1054b9f403.jpg'),
           ('Amaretto Sourball', 'https://m8g5e5y2.stackpathcdn.com/wp-content/uploads/2014/07/amaretto-sour-recipe-1.jpg'),
           ('Americana Fizz (Layered Cocktail)', 'https://www.thekitchenmagpie.com/wp-content/uploads/images/2017/06/AmericanFizzCocktail1.jpg'),
           ('And The Cherry On Top Is...', 'https://bigoven-res.cloudinary.com/image/upload/h_320,w_320,c_fill/cherry-on-top-a547a7cc509bef200d0c0d43.jpg'),
           ('Andy Warhol', 'https://s.hdnux.com/photos/11/21/16/2429852/6/rawImage.jpg'),
           ('Angel Face (Classic)', 'https://cdn.diffords.com/contrib/stock-images/2020/07/5f102bd439c31.jpg'),
           ("Angel's Face", 'https://www.liquor.com/thmb/XOFqpjrk0R8z9UwOVTToin_DZBo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/angels-face-720x720-primary-974a2f0bde394508b149e95fe272122f.jpg'),
           ('Aperitivo Spritz', 'https://cdn.diffords.com/contrib/stock-images/2018/1/34/2018af5d9ac30a3836c1449fd20d21616bba.jpg'),
           ('Apple Shrub Spritz', 'https://hips.hearstapps.com/hmg-prod/images/red-pear-shrub-spritz-recipe-1603395353.jpg'),
           ('Apples & Grapes', 'https://www.orchidsandsweettea.com/wp-content/uploads/2021/12/Apple-Cranberry-Martini-3-of-4.jpg'),
           ('Apricot Blush', 'https://www.freutcake.com/wp-content/uploads/2014/07/Apricot-Smash-Recipe-Card-scaled.jpg'),
           ('Arapa Cocktail', 'https://cdn.shopify.com/s/files/1/0508/9679/7877/files/1_0999436c-710b-411b-856d-8f3fb73c88fa.webp?v=1656822481'),
           ('Army and Navy', 'https://www.liquor.com/thmb/XkPUQBUl7NEwezobRGraTpXc0S0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/army-and-navy-720x720-primary-830563ea16d14a9e95fdd5ad59e16c57.jpg'),
           ('Asian Affair', 'https://www.powellandmahoney.com/wp-content/uploads/2016/12/20161209_powellmahoney_ablacktieaffair_6831.jpg'),
           ('Assemble Mule', 'https://www.acouplecooks.com/wp-content/uploads/2019/06/Moscow-Mule-062.jpg'),
           ('Astoria', 'https://assets-prd.punchdrink.com/wp-content/uploads/2020/11/23172756/Article-Astoria-Martini-Cocktail-Recipe.jpg'),
           ('Aviation (Adapted)', 'https://i0.wp.com/www.splashoftaste.com/wp-content/uploads/2022/10/aviation-cocktail-featured.jpg'),
           ('B and B', 'https://www.thespruceeats.com/thmb/Yyq_ULXURr_RXmiYTQ8-CK6PMRQ=/600x400/filters:max_bytes(150000):strip_icc()/cognac-grand-marinier-759411-hero-01-f474599bb4f747d9a903ff9684370d80.jpg'),
           ('B-String', 'https://www.restaurant-hospitality.com/sites/restaurant-hospitality.com/files/styles/article_featured_retina/public/uploads/2015/06/firsteveskisspromo_0.jpg?itok=1P17WwCQ'),
           ("Bachelor's Bait", 'https://www.lordbyronskitchen.com/wp-content/uploads/2021/05/2-5.jpg'),
           ('Bacio Romana', 'https://www.acouplecooks.com/wp-content/uploads/2020/05/Martinez-Cocktail-021.jpg'),
           ('Baile de Verano', 'https://assets-prd.punchdrink.com/wp-content/uploads/2021/05/31190403/Article-Tinto-de-Verano-Spritz-Recipe.jpg'),
           ('Bajo Control', 'https://californiagrown.org/wp-content/uploads/2022/09/IMG_4965.jpg'),
           ('Bakko & Zengo', 'https://www.chelseadishes.com/wp-content/uploads/2022/11/shaken-espresso-PB-featured.jpg'),
           ("Banana's Froster", 'https://tipsybartender.com/wp-content/uploads/2018/01/Bananas-Foster-Martini.jpg?fit=crop&ar=1:1'),
           ('Barbary Coast Bulldog', 'https://www.thespruceeats.com/thmb/J61ErKpRu_PsFXzJ8UGH4bCG39c=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/_colorado-bulldog-cocktail-761032-hero-5bc4f1b7c9e77c00510b3bf7.jpg'),
           ('Barrel Aged Ginger Negroni', 'https://thismessisours.com/wp-content/uploads/2022/04/IMG_5652.jpg'),
           ('Basil Gin and Tonic', 'https://www.cakenknife.com/wp-content/uploads/2016/08/Lemon-Basil-Gin-and-Tonic-Thumbnail-480x480.jpg'),
           ('Basilway Daquiri', 'https://tipsybartender.com/wp-content/uploads/2018/01/Basil-Daiquiri.jpg'),
           ('Bay City Shandy', 'https://jameslanepost.com/wp-content/uploads/2022/02/image001_ccexpress.jpeg'),
           ('Beachcomber', 'https://1.bp.blogspot.com/-_J2oN6fO_eY/YOSJ6gOl3aI/AAAAAAAAHJM/FGHHv_fDBekXglc4NFPEW8JxZhFWCxB7ACLcBGAsYHQ/s500/Beachcomber-Cocktail-047-websize-x500.jpg'),
           ("Bee's Knees" ,'https://www.liquor.com/thmb/NFzw_JJliBofheniy_KceB35msc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Bees-Knees-1200x628-email-94cb57d3a84640c9923846445241f112.jpg'),
           ('Bella Luna', 'https://preview.redd.it/7eyl48iqvqm51.jpg?auto=webp&s=ff8c226224a046b2c86728cc674b5726a56fef31'),
           ('Bianco Americano', 'https://www.liquor.com/thmb/cbOS9LzpLZpEEBvd9eZpvz509KI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/suzie-americano-720x720-primary-2204247097dd40418ab3f12b3801ba86.jpg'),
           ('Big and Bright', 'https://www.thedrinkkings.com/wp-content/uploads/2017/01/Ginger-Gin-Juice-3-630-630x852.jpg'),
           ('Bijou', 'https://www.liquor.com/thmb/5LXDhmResWbuLjJNeY-On_VuuZo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/bijou-720x720-primary-1c9765a51d85476897461c735eec0953.jpg'),
           ('Bird On', 'https://www.acouplecooks.com/wp-content/uploads/2021/03/Yellow-Bird-Cocktail-004.jpg'),
           ('Bird is the Word', 'https://prunesandgin.com/wp-content/uploads/2020/06/The-bird-is-the-word-500x700-4.jpg'),
           ('Bird on a Wire', 'http://www.idrink.com/drinkpics/47658.jpg'),
           ('Bird to Buck', 'https://assets.bacardicontenthub.com/transform/2cbc977d-cea9-46c9-a053-eebbb21e7a6d/FY21_US_Bacardi_Hero-Cocktail_Marketing_Asset_Jungle-Bird_PBX-tiff?io=transform:fit,width:2048,height:1152&format=webp&quality=95'),
           ('Bitter Mimosa', 'https://www.thespruceeats.com/thmb/8tgJvceDTVrW7394F43FqICJnTk=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/great-mimosa-recipe-759734-hero-1-50acafd7273d4c438cdb2f2f55a3ceea.JPG'),
           ('Bitter Valencia', 'https://www.thespruceeats.com/thmb/REawtovj4fQpeJTCMEfM_bDPwq4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/valencia-cocktail-recipe-759462-hero-01-61dbad975df04d369300fedcc53a3175.jpg'),
           ('Black Jam', 'https://livelytable.com/wp-content/uploads/2015/12/blackberry-gin-and-jam-4-1156x1536.jpg'),
           ('Blind Luck', 'https://static.spotapps.co/spots/69/8246ad305c464c9d8cfc81352b96e4/full'),
           ('Blinker', 'https://www.liquor.com/thmb/prEug5TpB_tCuAdv61r5uWmr0Bg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/blinker-720x720-primary-f94b798ec530487fa37d062ef63b063d.jpg'),
           ('Blood & Sand', 'https://www.liquor.com/thmb/RFXLLHRx6TpAwaJRuon7HHb4GYU=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/blood-and-sand-720x720-primary-a27c8e8da61b410facde9292b600d908.jpg'),
           ('Blood and Sand', 'https://www.acouplecooks.com/wp-content/uploads/2020/07/Blood-and-Sand-Cocktail-006.jpg'),
           ('Bloody Fernet', 'http://www.completecocktails.com/img/d/l/BloodyFernet.jpg'),
           ('Bloody Swede', 'https://img.delicious.com.au/yXt0MINq/w759-h506-cfill/del/2020/04/img_lonelymary-129532-1.jpg'),
           ('Blue 88', 'https://images.squarespace-cdn.com/content/v1/59652026f7e0abdb8c26159d/1644520722135-AF1D7AEFQFRQ15FERR9Q/curacao+lemonade.jpg'),
           ('Bobby Burns', 'https://www.liquor.com/thmb/0Rq27s2h64NnmEG49Pg7IvyxfYs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/bobby-burns-720x720-primary-dc5ddb0cecaf486abb23286735c0f734.jpg'),
           ('Boko Buku', 'https://images.squarespace-cdn.com/content/v1/5c0edbac620b85c81c022697/1666765310420-Z360ALPUJ6KVRML4GZHP/ramona1000x1000.png?format=1000w'),
           ('Bon Voyage Pisco Punch', 'https://images.squarespace-cdn.com/content/v1/597eb9bf86e6c03d802291e8/1598335364486-48SN89A1UL8BCN90KIA1/Pisco+Punch'),
           ("Boomin' Granny", 'https://media.cocktaillove.com/media/recipes/b85eb9dd-c83c-44bb-a7c3-7ecca462b1fe/brown-derby-UA18Oktn-360w.jpg'),
           ('Boulevard', 'https://www.liquor.com/thmb/LV0L3CF51hFJoSN-QdLe6ijXsFQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__liquor__2019__09__12094720__Boulevardier-720x720-recipe-53da547e8cfc4bd79a393ac99891f5ba.jpg'),
           ('Boulevardier', 'https://static01.nyt.com/images/2018/01/25/dining/25COOKING-Boulevardier1/25COOKING-Boulevardier1-articleLarge.jpg'),
           ('Bourbon Crusta', 'https://saltandwind.com/wp-content/uploads/2022/05/bourbon_crusta_cocktail_recipe_h-3-1536x1024.jpg'),
           ('Brazilian Mai Tai', 'https://cdn.shopify.com/s/files/1/0038/6049/6433/articles/Bartesian_maitai.jpg?v=1645063296'),
           ('Brazilian Mule Punch', 'https://galumbi.com/wp-content/uploads/2016/04/Brazilian-Mule-1-von-1-590x961.jpg'),
           ('Brisa del Sur', 'https://es.inshaker.com/uploads/cocktail/promo/994/square_1542205539-Southern-Sea-Breeze-_promo.jpg'),
           ('Bubbleliciously Delicious', 'https://pbs.twimg.com/media/B-4AR68XAAANWXp.jpg'),
           ('Bubbly Bird', 'https://www.seriouseats.com/thmb/NhNJD_iXHaS6SYK2yAjywybptNY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__serious_eats__seriouseats.com__recipes__images__2013__12__20131222-sparklingjunglebird-drink-62aa75240e2a4d988d16e1e685560ee0.jpg'),
           ('Buenaventura', 'https://scontent-bos5-1.xx.fbcdn.net/v/t39.30808-6/256071113_4423829727708942_2436919716612439284_n.jpg?stp=cp0_dst-jpg_e15_p320x320_q65&_nc_cat=108&ccb=1-7&_nc_sid=9e2e56&_nc_ohc=FowSAD4vc88AX8BR9WW&_nc_ht=scontent-bos5-1.xx&oh=00_AfCXb9OQMr4CHLMHs3YbQ7YT9sN5Yl8RVqpGgsycBntwjw&oe=644CCFED'),
           ('Bunny Poison', 'https://www.shakedrinkrepeat.com/wp-content/uploads/2021/03/drunk-bunny-3-683x1024.jpg'),
           ('Bushido Cocktail', 'https://cdn.shopify.com/s/files/1/0087/5085/8300/files/Cocktails_with_Bushido_web.jpg?967'),
           ('Buster Crusta', 'https://images.squarespace-cdn.com/content/v1/5bcccf8b9b7d15579477a125/1597523276543-LD9ZNNPPFLMOLHJ3JBKM/PSX_20200815_162638.jpg?format=1500w'),
           ('Buttermilk maple gin flip', 'https://sipsfromscripts.com/wp-content/uploads/2023/01/Buttermilk-Maple-Gin-Flip-Cocktail-Recipe-SipsFromScripts.webp'),
           ("Buzzard's Bay", 'https://images.squarespace-cdn.com/content/v1/5a04764ccd39c37015542403/1511193286611-QN0QQJPBF3RG6MFW5V89/Buzzards-Bay-Breeze-226x300.jpg'),
           ('Cafe Creole', 'https://d34nm4jmyicdxh.cloudfront.net/eyJidWNrZXQiOiJjaHJpc3N5LXR1eGVkby1ubzIiLCJrZXkiOiJjcmVvbGUtMi5qcGciLCJlZGl0cyI6eyJyZXNpemUiOnsid2lkdGgiOjYwMCwiaGVpZ2h0Ijo2MDAsImZpdCI6ImNvdmVyIn19fQ=='),
           ("California's Callin'", 'https://www.anchorbrewing.com/blog/wp-content/uploads/2017/03/San-Fran-Soda-Image-Low-Res.png'),
           ('Canary vs. the Coal Mine', 'https://www.thefoodlens.com/uploads/2017/06/VIALE_CANARY-IN-THE-COAL-MINE_COCKTAIL-OF-THE-WEEK_THE-FOOD-LENS_MAY-2017-4212.jpg'),
           ("Cap't of the Seven Seas", 'https://www.mantitlement.com/wp-content/uploads/2015/05/seven-seas-martini-top-1-300x300.jpg'),
           ('Carrier Pigeon (an Airmail with Pink Pigeon)', 'https://gardenandgun.com/wp-content/uploads/2014/07/GG0414_Drinks_01-733x1100.jpg'),
           ('Champs Élysées', 'https://imbibemagazine.com/wp-content/uploads/2020/12/champs-elysees-crdt-john-valls.jpg'),
           ('Chapman Cobbler', 'https://historyinthemakingcom.files.wordpress.com/2020/06/p1014659.jpg?w=1620'),
           ('Charente Royale', 'https://assets-prd.punchdrink.com/wp-content/uploads/2017/04/Slide-6-Drink-Trends-Pouring-Ribbons-Death-and-Co-NoMad-Trick-Dog-Cocktail-Recipe.jpg'),
           ('Cherries St. James', 'https://s3.eu-west-2.amazonaws.com/s3-stjames-istjames/images/journeys/a-mixology-tour-of-st-jamess/_1200x630_crop_center-center_82_none/Crown-Guide-Cover_Mixology-Tour_1500x825.jpg?mtime=1563913094'),
           ('Cherry Bark Martinez', 'https://cancanawards.com/wp-content/uploads/2022/08/Martinez-Cocktail-Recipe-1.jpg'),
           ('Cherry Blossom Martini', 'https://cheersonline.com/wp-content/uploads/2020/03/cherry-blossom.jpg'),
           ('Cherry Champagne Cocktail', 'https://veenaazmanov.com/wp-content/uploads/2021/01/Cherry-Champagne-Cocktail3-1.jpg'),
           ('Cherry Old Fashioned', 'https://jellytoastblog.com/wp-content/uploads/2016/02/Tart-Cherry-Old-Fashioned-10-of-15.jpg'),
           ('Cherry Orchard', 'https://en.araratbrandy.com/media/lxnmxtsr/792x384__0018_cherry-orchard.jpg'),
           ('Cherry Shandy', 'https://www.saveur.com/uploads/2019/03/18/TB2NGG7MIGR3D6R4EPSFMJ45FQ.jpg?auto=webp&auto=webp&optimize=high&quality=70&width=450&dpr=2'),
           ('Chilcano', 'https://www.thespruceeats.com/thmb/TOB8uHaYFdrN4_rwQ1MrXSeN-JI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/chilcano-de-pisco-peruvian-brandy-cocktail-3029216-step-04-298c98fbc5084a9eb6dd8b5338c77111.jpg'),
           ('Chilcano (variation)', 'https://www.baconismagic.ca/wp-content/uploads/2020/01/Chilcano-pisco-drink.jpg'),
           ('Chilli Vanilli', 'https://tendercrate.com/wp-content/uploads/Chili-Vanilli-TenderCrate.jpg'),
           ('Chingerito', 'https://www.muydelish.com/wp-content/uploads/2022/02/cantaritos.jpg'),
           ('Chippendale Rosetone', 'https://images.food52.com/d4vqJFkFfZ9ZFJdP-2PmkWLMfuc=/fit-in/1200x1200/7d77e604-3c53-4243-9395-31eebf00e14c--2018-1212_sponsored_cointreau_rosebud-cocktail_recipe-hero_3x2_julia-gartland_256.jpg'),
           ('Château Montifaud Creation', 'https://hips.hearstapps.com/toc.h-cdn.co/assets/16/41/1476199226-gettyimages-503700853-1.jpg?crop=0.889xw:1.00xh;0.0867xw,0&resize=980:*'),
           ('Château Montifaud Lady Touch Triple Sec', 'https://www.yuzubakes.com/sites/yuzubakes.com/files/styles/yct_adaptive_ls_scale_1440/public/freshtriple-sec-cocktail-served-in-a-beautiful-glass-decorated-with-rosemary.jpg'),
           ('Château Montifaud Pink Love', 'https://s.yimg.com/ny/api/res/1.2/nCotgD5HwEPnbFzL1aaZlA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTY0MDtoPTQyNw--/https://media.zenfs.com/en/town_country_721/80922c83ed8beeab1d1ae5ca94a9ff25'),
           ('Château Montifaud on Mint', 'https://imbibemagazine.com/wp-content/uploads/2013/07/baroness-collins-mint-gallery-crdt-justen-clay.jpg'),
           ('Château Montifaud on the Rocks', 'https://hips.hearstapps.com/toc.h-cdn.co/assets/16/41/1476199509-gettyimages-164770343.jpg?crop=1.0xw:1xh;center,top&resize=980:*'),
           ('Citrus Agave Caipirinha', 'https://www.thespruceeats.com/thmb/3xr8op_rQ67pjyRqho9RUq1BY7I=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/caipirinha-recipe-759290-hero-01-d599e690fbae40238c20a6137ebb52ef.jpg'),
           ('Citrus Quo (Adapted)', 'https://mybartender.com/wp-content/uploads/2023/03/citrus-cocktails-720x720.jpg'),
           ('Classic Lolita', 'https://www.thefoodlens.com/uploads/2018/10/LOLITA_COTW_DIABLO_THE-FOOD-LENS_BRIAN-SAMUELS-PHOTOGRAPHY_OCTOBER-2018-0065-copy.jpg'),
           ('Clear Intentions', 'https://www.flairprojectsb.com/wp-content/uploads/2020/09/easy-clarified-margarita-recipe.jpg'),
           ('Clearly Bitter', 'https://static1.squarespace.com/static/561d9595e4b039470e9966f2/t/5f0f748fbb28902a7fe3990e/1594848941236/Crystal+Clear+2.jpg?format=1500w'),
           ('Clover Holiday Cocktail', 'https://www.supergoldenbakes.com/wordpress/wp-content/uploads/2016/02/Clover_leaf_cocktail_1_s-4.jpg'),
           ('Club Med', 'https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/52/76/94/qGluGNFTRhamqf82rK3w_clubmedbahama.jpg'),
           ('Cocao Martini', 'https://preppykitchen.com/wp-content/uploads/2020/08/Chocolate-martini-feature.jpg'),
           ('Cock-tail', 'https://i.guim.co.uk/img/media/899f4700a61a9ee02a0f1dea371fb046d1907c73/0_3027_8656_5193/master/8656.jpg?width=1200&height=900&quality=85&auto=format&fit=crop&s=e7f1493e4e8816fd90250225d24ec18b'),
           ('Coco Batida', 'https://braziliankitchenabroad.com/wp-content/uploads/2019/09/batida-de-coco-3.jpg'),
           ('Coffee & Clove', 'https://sugarandcloth.com/wp-content/uploads/2019/05/Coffee-Old-Fashioned-Ashley-3.jpg'),
           ('Coffey Grain Manhattan', 'https://www.cocktailcontessa.com/wp-content/uploads/2020/04/Coffee-Manhattan-1.jpg'),
           ('Conference', 'https://sipsfromscripts.com/wp-content/uploads/2022/05/Conference-Cocktail-Recipe-SipsFromScripts.webp'),
           ('Coos Bay', 'https://images.otstatic.com/prod/25209368/1/huge.jpg'),
           ('Corpse Reviver No 1', 'https://www.liquor.com/thmb/g7g_4WIdUiMDkGer-bJe9S22RmQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__liquor__2018__10__12094653__Corpse-Reviver-No-1-720x720-recipe-f419716475c842bc94d3c29dcb6764e6.jpg'),
           ('Corpse Reviver No.2', 'https://www.liquor.com/thmb/noPxyC3lcDdEyaokaXmqY5Iqrp0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/corpse-reviver-no2-720x720-primary-0e720a14bee34038864c97d341f0e0ed.jpg'),
           ('Cream of the Crop', 'https://www.liquor.com/thmb/cAvQs4syO8uD4hvjII1dWGFMMi0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/cream-of-the-crop-720x720-primary-3bb19fd6e000423bbf1e644dbaa97634.jpg'),
           ('Creek Ran Dry', 'https://images.getrecipekit.com/20210827061004-boozy_lemon.jpg?aspect_ratio=16:9&quality=90&'),
           ('Creole', 'https://cdn.shortpixel.ai/spai/q_lossless+w_1341+to_webp+ret_img/https://imbibemagazine.com/wp-content/uploads/2019/07/cane-table-creole-cocktail-crdt-melanie-estopinal.jpg'),
           ('Creole Cobbler', 'https://www.disneyfoodblog.com/wp-content/uploads/2020/03/ralph-brennans-jazz-kitchen-downtown-disney-food-and-wine-festival-creole-cobbler-cocktail-12.jpg'),
           ('Creole Summer', 'https://cdn.shopify.com/s/files/1/0583/3185/products/creole_smash_square_1200x.jpg?v=1523551712'),
           ('Croatia Firing Squad', 'https://www.patrontequila.com/binaries/largeretina/content/gallery/patrontequila/recipes/roca-patron-silver/mexican-firing-squad/mexican-firing-squad.jpg'),
           ('Crooked Kilt', 'https://i.redd.it/mjvcjsxgb1461.jpg'),
           ('Cuba Liberation', 'https://www.196flavors.com/wp-content/uploads/2018/09/cuba-libre-1-FP.jpg'),
           ('Culebra', 'https://www.patrontequila.com/binaries/largeretina/content/gallery/patrontequila/recipes/roca-patron-reposado/culebra-cascabel/onwhite_culebracascabel.jpg'),
           ('Cullerton Street', 'https://stevedolinsky.com/wp-content/uploads/2015/09/IMG_6535.jpg'),
           ("Cupid's Carrier Pigeon", 'https://mamasonabudget.com/wp-content/uploads/2022/01/Cupid_s-Cocktail-30-683x1024.jpg'),
           ('Cut & Rum', 'https://images.squarespace-cdn.com/content/v1/5a4d1c557131a5e3e04d9e2a/1608221642564-8P71Z0268D47XAETDJHV/DSC_2093-3.jpg'),
           ('Cut To The Chase', 'https://www.forkinthekitchen.com/wp-content/uploads/2016/06/210622.watermelon.mint_.cocktail.updated-9993-13.jpg'),
           ('Cut and Run', 'https://newdealdistillery.com/wp-content/uploads/2023/03/new-deal-two-tickets-768x768.jpg'),
           ('Cynar Toronto', 'https://foodworthfeed.com/wp-content/uploads/2021/03/9T7A9116.jpg'),
           ('Cynartown', 'https://media.cocktaillove.com/media/recipes/602a86be-3c5c-4e05-b66d-81048f2c0c54/cynartown-N6cXatDY-1080w.jpg'),
           ('Daisy Mae', 'https://www.davidlebovitz.com/wp-content/uploads/2020/05/May-Daisy-cognac-chartreuse-lemon-mint-cocktail-pdt-phil-ward-6.jpg'),
           ('Day For Night', 'https://dishesdelish.com/wp-content/uploads/2019/07/Night-and-Day-Cocktail-7.jpg.webp'),
           ('Delicious Sour', 'https://img.delicious.com.au/roBvkIa7/w759-h506-cfill/del/2020/12/classic-sour-143897-1.jpg'),
           ('Delicious in Mauritius', 'https://www.lifeberrys.com/img/article/cocktails-in-mauritius-1588679523-lb.jpg'),
           ('Derby cocktail', 'https://www.seriouseats.com/thmb/bgx4Vjcc-9oOzmvb-noqqu4VkTY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/__opt__aboutcom__coeus__resources__content_migration__serious_eats__seriouseats.com__recipes__images__2011__10__20111003derbyprim-adf52f6b41594010ae211c2ef065a6d0.jpg'),
           ('Dernier Mot', 'https://cocktailsdistilled.com/wp-content/uploads/2021/07/Gingeer-Mon-2-565x565.jpg'),
           ("Desmond's Choice", 'https://assets-mainlinetoday-com.s3-accelerate.amazonaws.com/2015/08/open_bigsipaug.jpg'),
           ('Deviled Negroni', 'https://d3h1lg3ksw6i6b.cloudfront.net/media/image/2018/06/06/ed0c0de847614d75a00f8affab7c96db_shutterstock_563706778.jpg'),
           ('Dirt Nap', 'https://gardenandgun.com/wp-content/uploads/2014/03/IMG_0341.jpg'),
           ('Divine Aspect', 'https://www.gastronomblog.com/wp-content/uploads/2022/08/Dampfweks-Distilling-13.jpg'),
           ('Division Bell', 'https://www.liquor.com/thmb/1p-jMcxt4TSF2ANkTaO0NO1PTr0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/division-bell-720x720-primary-1490c96136dd4514a9238eb30dde4a79.jpg'),
           ("Doctor's Orders", 'https://www.sunset.com/wp-content/uploads/sunset-sips-doctors-orders-pr-0520-900x500.jpg'),
           ("Don't Rock the Boat Punch", 'https://www.liquor.com/thmb/4vnHI8O8UC1Jk5qVe3Sjb3kyZCc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/__opt__aboutcom__coeus__resources__content_migration__liquor__2019__06__18113946__beat-house-punch-720x720-recipe-3d8eece01a2b4e3a930500df7fb6532a.jpg'),
           ('Donaji', 'https://jbf-media.s3.amazonaws.com/archive/jbf-2013/recipes/donaji_cocktail.jpg'),
           ('Double Trouble', 'https://www.mantitlement.com/wp-content/uploads/2017/05/double-trouble-tropical-tequila-shots-double-698x1024.jpg'),
           ('Simply Perfecto', 'https://assets-prd.punchdrink.com/wp-content/uploads/2014/07/Americano-Perfecto.jpg'),
           ('Singapore Sling (1915 Recipe)', 'https://www.saq.com/media/catalog/product/s/i/singapore-petillant-ec-1_1610405160.png?width=506&height=550&canvas=506,550&quality=80&fit=bounds'),
           ('Sloe & Steady', 'https://imbibemagazine.com/wp-content/uploads/2015/12/sloeunsteady-drink-well-austin-vertical-crdt-jody-horton.jpg'),
           ('Slow Ride', 'https://www.easy-cocktail-recipes.net/v2/webp/13521-480x320.webp'),
           ('Smashing Great Pumpkins', 'https://www.liquor.com/thmb/vi-NkhmQeSTGphocKByP9Ov6UtM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/smashing-pumpkin-720x720-primary-96e1b142d1b1417a9316fed3bfc07d64.jpg'),
           ('Smoke On The Dock', 'https://www.liquor.com/thmb/0je0XSZ3X5jwbrhttWTFcKG14m0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/smoke-on-the-water-720x720-primary-a7c6b92874914d2ab2c34972cf2a013e.jpg'),
           ('Snow Bunny', 'https://mscwordpresscontent.s3.amazonaws.com/wa/wp-content/uploads/2018/01/Snow-Bunny-1600.jpg'),
           ('Soleo', 'http://www.completecocktails.com/img/d/l/Soleo.jpg'),
           ('Solera Sidecar', 'https://soleratt.com/wp-content/uploads/2021/08/sidecar.png'),
           ('Sorrentino', 'https://cdn.diffords.com/contrib/encyclopedia/2021/08/6115170d6119f.jpg'),
           ('Sorriso (Adapted)', 'http://www.completecocktails.com/img/d/l/Sorriso.jpg'),
           ('Space Age Pop', 'https://www.taketwotapas.com/wp-content/uploads/2017/06/Astro-Pop-Cocktail-7.jpg'),
           ('Spanish G&T', 'https://assets-prd.punchdrink.com/wp-content/uploads/2021/05/24003625/Article-Spanish-Gin-and-Tonic-Recipe.jpg'),
           ('Speyside Orchard', 'https://www.speyburn.com/assets/000/000/216/HOPKINS-APPLE-HIGHBALL-CUTOUT_cocktail.png?1665516155'),
           ('Spice and Stormy', 'https://assets.bonappetit.com/photos/57add934f1c801a1038bcc4f/master/w_940,h_671,c_limit/spiced-dark-and-stormy3.jpg'),
           ('Spiced Marmalade', 'https://images.ricardocuisine.com/services/recipes/a-cocktailrhumepicericardo-automne223601-cmyk.jpg'),
           ('Spring Cleanse', 'https://simmerandsauce.com/wp-content/uploads/2017/10/fullsizeoutput_16ff9.jpeg'),
           ('Spring Forward', 'https://assets.epicurious.com/photos/54f8aa064f77a310045dcb04/master/w_2000,h_1333,c_limit/rosemarycocktail.jpg'),
           ('Still Life of a Pineapple', 'https://images.squarespace-cdn.com/content/v1/5402e23ce4b0a7034afad3a2/1597141041536-K1CMKIPLQ3NSCNCQR9WZ/Pineapple+and+gin+martini'),
           ('Stone Fruit Patch V1', 'https://americas-table.com/wp-content/uploads/2015/08/Stone-fruit-cocktails-photo-5-Aug-14.jpg'),
           ('Stone Fruit Patch V2', 'https://s.yimg.com/ny/api/res/1.2/6AP1p9i38uVDUXodjuhaXg--/YXBwaWQ9aGlnaGxhbmRlcjtoPTY2Ng--/http://magazines.zenfs.com/resizer/original/e3Yv9rHV7l97GaLtWgNOJr9aaHE'),
           ('Stranger in the Alps', 'https://www.liquor.com/thmb/xPV3MM3BJCYB-yuYev9WLQr7Opc=/440x440/filters:max_bytes(150000):strip_icc()/kingston-negroni-720x720-primary1-ef87562fea8240de92dd09c36457a8c2.jpg'),
           ('Strike No.3', 'https://mixthatdrink.com/wp-content/uploads/2010/09/ten-strike-drink.jpg'),
           ('Stroll Through the Park', 'http://www.completecocktails.com/img/d/l/WalkInThePark.jpg'),
           ('Swedish 75', 'https://true-north-kitchen.com/wp-content/uploads/2021/02/swedish-75-2-800x1200.jpg'),
           ('Swedish Nightingale', 'https://netenrich.com/hubfs/Nightengale-Drink-1.png'),
           ('Swedish Royal', 'https://3.bp.blogspot.com/-MYN-zH20B-Y/WaSbmk7f3JI/AAAAAAAAE_g/nVb4DLNTSlUb0286GE2fk6jTyCJLqin-gCLcBGAs/s320/suedoise807.jpg'),
           ('Tahitian Fix', 'https://hips.hearstapps.com/hmg-prod/images/classic-cocktails-negroni-1669679541.jpeg?crop=1.00xw:0.506xh;0,0.157xh&resize=1200:*'),
           ('Tamaulipas Margarita', 'https://www.cakenknife.com/wp-content/uploads/2015/12/Big-Batch-Holiday-Sangria-Thumbnail-244x320.jpg'),
           ('Tambourine', 'https://us.inshaker.com/uploads/cocktail/hires/1027/icon_1556453356-Earl_grey_gimlet-image.jpg'),
           ('Tea & Sympathy', 'https://gluttonforlife.com/uploads/4600046/1478827933600/toddy2-790-xxx.jpg'),
           ('Tea Party Cocktail', 'https://cdn.diffords.com/contrib/stock-images/2016/7/26/2016d295837680d506623e7dfefee691fbb3.jpg'),
           ('Temple of the Moon', 'https://images.squarespace-cdn.com/content/v1/591f4a98414fb5698275ff3b/1593638924625-IRRVA4IMVJR6W87FKKUQ/DSC_0375.jpeg'),
           ('Tequila Sunflare', 'https://cdn.imgbin.com/18/23/18/imgbin-orange-juice-tequila-sunrise-cocktail-bloody-mary-orange-juice-2c6RhdY3NvTK10ArsJ8sXZGXj.jpg'),
           ('The 42nd Round', 'https://www.anchorbrewing.com/blog/wp-content/uploads/2016/12/The-42nd-Round.jpg-lo-res.png'),
           ('The Alpine Mist', 'https://imbibemagazine.com/wp-content/uploads/2017/09/lush-life-horizontal-crdt-tk.jpeg'),
           ('The Asterisk', 'https://bevvyco.s3.amazonaws.com/img/drinks/hy/obhy/3d46dacedbb52a1c7eb93bd010421750-lg.jpg'),
           ('The Awen', 'https://scontent-lga3-1.xx.fbcdn.net/v/t39.30808-6/277677258_5565239346838672_8947222340177979397_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=8bfeb9&_nc_ohc=Jq2t1YPXdy8AX96aE8p&_nc_ht=scontent-lga3-1.xx&oh=00_AfBqKaVmm5vRG1ZbCiLAOr8T9ekfece0AWn-dHHj1d_DKw&oe=644C1EF5'),
           ('The Bacchus Cocktail', 'https://us.inshaker.com/uploads/cocktail/hires/180/1556812800-Bacchus__highres.jpg'),
           ('The Big Picture', 'https://www.opentable.com/blog/wp-content/uploads/sites/108/2017/05/Blog-Three_Dots-Credit-Jeff-Marini-copy.jpeg'),
           ('The Bitter King', 'https://images.squarespace-cdn.com/content/v1/5a1cb9fafe54efb296265169/1534519954361-OZ0WCYT6U6G28RKD30UT/IMG_5580-2.jpg'),
           ('The Bittered Valley', 'https://www.madriverdistillers.com/wp-content/uploads/2020/04/Bitter-Mai-Tai-Rev.jpg'),
           ('The Bossa Nova', 'https://cdn.diffords.com/contrib/stock-images/2016/7/23/2016da1cc55a2ebeec3f5651a9d9f36f64e0.jpg'),
           ('The Boys of Summer Cup', 'https://miro.medium.com/v2/resize:fit:1200/1*B94airB0v2vtFZugZMKlOQ.jpeg'),
           ('The Brightside', 'https://www.patrontequila.com/binaries/largeretina/content/gallery/patrontequila/recipes/roca-patron-silver/green-with-envy/cocktaillab_345x345_greenwithenvy.jpg'),
           ('The Callas Cocktail', 'https://www.callasconfiture.be/wp-content/uploads/2022/07/2022-07-FOTO-cocktail-600x600.png'),
           ('The Canevari Cocktail', 'https://cdn.diffords.com/contrib/stock-images/2015/8/00/20152972cacc722a4ab62908f29a3b985122.jpg'),
           ('The Cappa', 'https://cdn.diffords.com/contrib/stock-images/2018/05/5af3157f57e3e.jpg'),
           ('The Cavalier White Lady', 'https://cdn.diffords.com/contrib/stock-images/2016/1/58/2016f9140a04070a4c4baa05f844ffacf264.jpg'),
           ('The Chief', 'https://mscwordpresscontent.s3.amazonaws.com/wa/wp-content/uploads/2018/10/Big-Chief-cocktail-only_1600.jpg'),
           ('The Claridge', 'https://i2.wp.com/dishesdelish.com/wp-content/uploads/2019/07/Claridge-Cocktail-square-1.jpg'),
           ('The Cliffdiver', 'https://media.timeout.com/images/105528581/750/422/image.jpg'),
           ("The Commissioner's Trophy #3", 'https://cook.fnr.sndimg.com/content/dam/images/cook/fullset/2011/8/9/0/CC-Halloween_Black-Devil-Martini_s4x3.jpg.rend.hgtvcom.616.462.suffix/1348841829819.jpeg'),
           ('The Double Crown', 'https://dinedreamdiscover.com/wp-content/uploads/2022/03/2-Ingredient-Southern-Peach-Crown-Royal-Cocktail-6-720x720.jpg'),
           ('The Douglas Tilden', 'https://cdn1.vox-cdn.com/uploads/chorus_asset/file/8043277/DouglasRoom_PChang_7456.jpg'),
           ('The Fall 75', 'https://fabeveryday.com/wp-content/uploads/2021/12/Pinterest-Live-Fall-75-cocktail.jpg'),
           ('The French Connection', 'https://www.liquor.com/thmb/IBQ2BKYje9S__vkQSMO8NG0_934=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/french-connection-720x720-primary-424103533cfe4e9e8522945d0568f3d4.jpg'),
           ('The Fritz', 'https://www.shakeitdrinkit.com/recette/mini/dory-fritz-cocktail-763.png'),
           ('The Ginger Royale', 'https://sipsmith.com/wp-content/uploads/sites/4/2018/05/Ginger-Royale-Portrait-Sipsmith-London-Dry-Gin-768x1152.jpg'),
           ('The Great Pumpkin Cocktail', 'https://www.liquor.com/thmb/u8lQVXwUR04ufCbx1vCPfWD8KAg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/great-pumpkin-720x720-primary-4e5e2da7b3ed4e8e8b60b5b556ea2637.jpg'),
           ('The Happy Place', 'https://images.ctfassets.net/ltric1hkjv72/2WleEhtQQCWuZUn49mAhkD/1657706b6a83f692be7674604e51629a/210128_Recipe15334.jpg?w=3840'),
           ('The Hollinger Manhattan', 'https://i0.wp.com/www.smugmug.com/photos/919836455_v27WE-XL.jpg'),
           ('The House of Duncan', 'https://food.fnr.sndimg.com/content/dam/images/food/fullset/2020/12/10/0/FNM_010121-Isadora-Duncan.jpg.rend.hgtvcom.616.462.suffix/1607613553932.jpeg'),
           ('The Improved Sazerac', 'https://www.liquor.com/thmb/4SBscQ08AosVxR0BQ2U3Vyz2K-M=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/original-sazerac-720x720-primary-85570828fe894c04a13bd414aaa130e8.jpg'),
           ('The Inside Job', 'https://i.pinimg.com/originals/2f/25/3b/2f253b2ede2b613320de87f450fc068e.jpg'),
           ('The Italian Diplomat', 'https://bloximages.newyork1.vip.townnews.com/channel3000.com/content/tncms/assets/v3/editorial/a/42/a42d7f24-59e2-53a7-98b3-62f81e0421ad/63b79900465b6.image.jpg'),
           ('The King Merlet Sidecar', 'http://lucyfg.com/wp-content/uploads/2015/05/9108268_orig.png'),
           ('The King and Tonic', 'http://www.completecocktails.com/img/d/l/KingAndTonic.jpg'),
           ("The King's Autumn Cobbler", 'https://assets-prd.punchdrink.com/wp-content/uploads/2016/11/27151132/Article-Kings-Cobbler-Sfumato-Amaro-Cocktail-Recipe.jpg'),
           ("The King's Cranberry Sauce", 'https://www.theroastedroot.net/wp-content/uploads/2014/11/cranberry-sauce-bourbon-cocktail-5.jpg.webp'),
           ("The King's Egg Nog", 'https://jeffreymorgenthaler.com/wp-content/uploads/2020/10/JAM_6674-684x1024.jpg'),
           ("The King's Froth & Frizz", 'https://cf.ltkcdn.net/cocktails/images/std/286398-800x533-gin-fizz.jpg'),
           ("The King's Ginger Spiced Punch", 'https://static.standard.co.uk/s3fs-public/thumbnails/image/2014/11/11/16/KGL-Mulled-Cyder-.jpg'),
           ("The King's Ginger Summer Cup", 'https://www.thedrinkblog.com/wp-content/uploads/2015/06/tdb-kings-summer-cup-1500x1000-2-1.jpg'),
           ("The King's Medicine", 'https://bakedbree.com/wp-content/uploads/2014/02/kings-cup_8.jpg.webp'),
           ("The King's Mulled Cider", 'https://blog.bbr.com/wp-content/uploads/2020/12/KGL-Cocktail-Square.jpg'),
           ("The King's Mulled Wine", 'https://static.lsm.lv/media/2020/12/large/1/ehbb.jpg'),
           ("The King's Queen", 'https://cdn.diffords.com/contrib/stock-images/2019/05/5ce7bbfc3acd6.jpg'),
           ("The King's Spring Daisy", 'http://www.completecocktails.com/img/d/l/SpringDaisy.jpg'),
           ("The King's Squeeze", 'http://www.completecocktails.com/img/d/l/KingsSqueeze.jpg'),
           ("The King's Winter Cup", 'http://www.completecocktails.com/img/d/l/WinterCup.jpg'),
           ('The Kings Mule', 'https://distillerienoroi.com/wp-content/uploads/2021/06/King-Mule-848x1080.jpg'),
           ('The Lady Whisper', 'https://i.ytimg.com/vi/4z2jLugkt5I/hqdefault.jpg'),
           ('The Ladybird', 'https://www.monin.com/media/catalog/product/cache/086f110b92ec89cebc323a4780ab42bd/3/3/335f3572-1541-46b7-b061-cd8f7e45b2d0-2.png'),
           ('The Last Marasca', 'https://www.sidechef.com/recipe/8af2388c-be39-452e-9edb-8bbeb44f752c.jpg?d=1200x560'),
           ('The Last Tango', 'https://assets.epicurious.com/photos/56d8c21815dc71625d4da719/16:9/w_1280,c_limit/The-Last-Tango-(c)-Mia-Wasilevich.jpg'),
           ('The Last Wish', 'https://cdn.diffords.com/contrib/stock-images/2019/10/5da6d37eeb0f9.jpg'),
           ("The Lover's Quarrel", 'https://lisakadane.files.wordpress.com/2015/02/lovers_quarrel_eau_claire_gin.jpg'),
           ('The Mad King', 'https://cdn.shopify.com/s/files/1/0497/5542/2869/products/DSC03927-2_600x.jpg?v=1637609750'),
           ('The Mayan Premonition', 'http://www.completecocktails.com/img/d/l/MayanPremonition.jpg'),
           ('The Molino', 'https://2.bp.blogspot.com/-XWikAsVIwSs/WYuUvk0JDLI/AAAAAAAADzg/6JO2mhjot40_SVpv9RojSCw3pu_7h8iFQCLcBGAs/s320/bournemouth170.jpg'),
           ('The Monte Rua', 'https://media-cdn.tripadvisor.com/media/photo-s/1d/67/90/a0/nos-copos-cocktail-bar.jpg'),
           ('The Naughty & Nice', 'https://kitchenfunwithmy3sons.com/wp-content/uploads/2022/12/Naughty-and-Nice-Cocktail-4-500x500.jpg'),
           ('The No.3 Winter Cup', 'https://assets-prd.punchdrink.com/wp-content/uploads/2018/12/Article-Cranberry-Blood-Orange-Pimms-Cup-Winter-Cocktail-Recipe.jpg'),
           ('The No.3 Winter Punch','https://cdn.diffords.com/contrib/stock-images/2017/3/30/2017bf7e2c6967497ffabfb3c60b97cda330.jpg'),
           ('The Nutty Sensation', 'https://www.thespruceeats.com/thmb/HzitxW7NCvkU7P631VsJass-rcc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/_4-recipes-for-the-popular-nutty-irishman-drink-759747-hero-2-5bd31dbec9e77c0058827d11.jpg'),
           ('The Palace Cellar', 'https://anerdcooks.com/wp-content/uploads/2017/06/palace_cafe_cocktail2-500x375.jpg'),
           ('The Pink Aperitivo', 'https://fevertree.s3.eu-west-2.amazonaws.com/thumbs/x500/78abab51ccc88b772a0d9f4dd4f20e62.jpg'),
           ('The Pink Pussycat', 'https://hips.hearstapps.com/delish/assets/cm/15/10/54f6b73e45ea8_-_cosmo-pinkpcat-xl.jpg'),
           ('The Professor', 'https://mangosalsa.net/wp-content/uploads/2019/04/IMG_5692-1170x680.jpg'),
           ('The Proverb', 'https://cookingwithelo.com/wp-content/uploads/2022/12/Cocktail-with-maraschino-cherry-5.jpg'),
           ('The Queen Mother', 'https://cdn.diffords.com/contrib/stock-images/2019/09/5d72589d15a1a.jpg'),
           ("The Queen's A Redhead", 'https://wp.supergoldenbakes.com/wordpress/wp-content/uploads/2014/12/The_red_queen_3.jpg'),
           ('The Red Anchor', 'https://anchorspa.square.site/uploads/1/3/1/4/131447595/s104361299448444582_p77_i1_w912.jpeg?width=1200&optimize=medium'),
           ('The Reserved King', 'https://assets3.thrillist.com/v1/image/2747581/828x610/flatten;crop;webp=auto;jpeg_quality=60.jpg'),
           ('The Rickenbacker', 'https://brandsforfans.com/app/uploads/sites/8/2019/05/rickenbacker-rickey-low-res.jpg'),
           ('The Robert Baratheon', 'https://i.pinimg.com/736x/57/1d/ec/571deca29b21a516e899e7f73780cb32.jpg'),
           ('The Royal Buck', 'https://www.crownroyal.ca/dist/images/cr-summer-crown-buck.jpg'),
           ('The Royal King', 'https://www.inspiredtaste.net/wp-content/uploads/2011/10/Kir-Royale-Recipe-2-1200.jpg'),
           ('The Rusty Tack', 'https://cdn.diffords.com/contrib/stock-images/2017/1/18/201742464c38bb003eed3ca283ac9f4b9a02.jpg'),
           ('The Seniorita', 'https://hips.hearstapps.com/hmg-prod/images/delish-191022-pink-senoritas-0325-portrait-pf-1579184990.jpg?crop=1.00xw:0.668xh;0,0.270xh&resize=980:*'),
           ('The Silver Cocktail', 'https://veganinthefreezer.com/wp-content/uploads/2018/09/Silver-Cadillac-Margarita-feature.jpg'),
           ('The Sixth Sense', 'https://us.inshaker.com/uploads/cocktail/promo/214/1542205163-The-Sixth-Sense-_promo.jpg'),
           ('The Southside', 'https://cdn.diffords.com/contrib/stock-images/2017/1/35/20171224f7476c95b6d4235a86638ddc37c8.jpg'),
           ('The Sparkler', 'https://domestikatedlife.com/wp-content/uploads/2014/12/grapefruit-sparkler-cocktail-1.jpg'),
           ('The Stand By', 'https://us.inshaker.com/uploads/cocktail/hires/624/1556463256-Stand-By-Me__highres.jpg'),
           ('The Sun Also Rises', 'https://cocktaildudes.com/wp-content/uploads/2013/04/KO7A1462.jpg'),
           ('The Swedish', 'https://cdn.diffords.com/contrib/stock-images/2017/1/43/20175f8183127d9a304a266241c7405b5eb3.jpg'),
           ('The Tahoe Toddy', 'https://ediblerenotahoe.com/wp-content/uploads/2010/11/drinkable-reno-tahoe-toddy-1.jpg'),
           ('The Touch  of Glass', 'https://media.cntraveler.com/photos/53da90236dec627b149f31e1/16:9/w_1280,c_limit/truffle-old-fashioned-cocktail-canon-seattle.jpg'),
           ('The Twinger', 'http://www.completecocktails.com/img/d/l/Twinger.jpg'),
           ('The Windtalker', 'http://www.completecocktails.com/img/d/l/Windtalker.jpg'),
           ('Three Flips', 'https://cdn.diffords.com/contrib/stock-images/2019/09/5d7256e769224.jpg'),
           ('Thyme for Bed', 'https://assets.wsimgs.com/wsimgs/ab/images/dp/recipe/202244/0056/img49l.jpg'),
           ('Toasted Drop', 'http://www.completecocktails.com/img/d/l/ToastedDrop.jpg'),
           ('Tokyo Tea', 'https://tipsybartender.com/wp-content/uploads/2018/03/tokyo-iced-tea.jpg'),
           ('Toronto', 'https://cdn.diffords.com/contrib/stock-images/2015/7/59/20151b06c02f69a8e49cbf6210c2a788e430.jpg'),
           ('Trato Hecho', 'https://bloximages.newyork1.vip.townnews.com/feastmagazine.com/content/tncms/assets/v3/editorial/2/4b/24bdc83e-b47c-11e9-abc2-ab1966242641/5d4317c9a93f7.image.jpg'),
           ('Trip to Jarnac', 'https://dishesdelish.com/wp-content/uploads/2016/06/Jarnac-Sour-Cocktail-square-1.jpg.webp'),
           ('Tropical Bronzer', 'http://www.completecocktails.com/img/d/l/TropicalBronzer.jpg'),
           ('Twentieth Century', 'https://imbibemagazine.com/wp-content/uploads/2019/02/anatomy-20th-century-cocktail-crdt-john-valls-dk.jpg'),
           ('Under the Sun', 'https://cdn.shopify.com/s/files/1/1216/2612/files/main_7301d58a-da78-40ad-9194-63b3ad598a50.png?v=1590248058'),
           ('Venetian', 'https://cdn.diffords.com/contrib/stock-images/2017/1/10/2017ea2abb69781fc6ff5fe776c9038b2fa1.jpg'),
           ("Vesper's Sister", 'https://preview.redd.it/vesper-martini-v0-l5x2ea4yznoa1.jpg?width=640&crop=smart&auto=webp&s=a31245fc5c66894cfc533a12170630b7d89928d5'),
           ('Vida Verde (Adapted)', 'https://www.thedailymeal.com/img/gallery/vida-verdes-gimme-mora-cocktail/gimmemora.jpg'),
           ('Vieja Moda', 'https://www.bcliquorstores.com/sites/default/files/recipe/AgaveAGoGo_TequilaViejaModa_1672.jpg'),
           ('Vieux Carré', 'https://imbibemagazine.com/wp-content/uploads/2010/07/vieux-carre-vertical-crdt-emma-janzen.jpg'),
           ('Vieux carre', 'https://imbibemagazine.com/wp-content/uploads/2010/07/vieux-carre-vertical-crdt-emma-janzen.jpg'),
           ('Vintage Reserve Sour', 'https://images.squarespace-cdn.com/content/v1/59c3feb149fc2b152179e47e/1520648804699-CX0F873KFGPU2GA3TA37/Whiskey_Sour_BeautifulMess.jpg'),
           ('Vinterpäls', 'https://cdn.thismamacooks.com/images/2014/12/hot-toddy-with-tea-1.jpg'),
           ('Virgil St.', 'https://www.virgilsbbq.com/assets/uploads/general/CMS_VLV_Menu-Section_Header_Whiskey-Drinks.jpg'),
           ('Wabash Avenue Sour', 'https://www.restlesschipotle.com/wp-content/uploads/2015/01/whiskey-sour-1.jpg'),
           ('War of the Roses', 'https://www.great-taste.net/wp-content/uploads/2017/01/war-of-the-roses-cocktail.jpeg'),
           ('West Bank', 'https://cdn.diffords.com/contrib/stock-images/2019/04/5cc823f2bc23a.jpg'),
           ('West Coast Punch', 'https://assets-prd.punchdrink.com/wp-content/uploads/2023/03/28153850/Article-Painful-Punch-Culinary-Cocktail-West-Coast-Style.jpg'),
           ('West Coast Vesper', 'https://shake-that.com/wp-content/uploads/2015/07/Vesper1.jpg'),
           ("Where's the Orgeat?", 'https://imbibemagazine.com/wp-content/uploads/2015/08/faro-charos-kick-vertical-crdt-michael-ulipan1.jpg'),
           ('White Lady (Classic) (Adapted)', 'https://tastecocktails.com/wp-content/uploads/2015/12/white-lady-serious-eats.jpg'),
           ('White Tie', 'https://cocktailpartyapp.com/wp-content/uploads/White-Tie-Tiara.png'),
           ('White Walker Flip', 'https://i0.wp.com/munchiesandmunchkins.com/wp-content/uploads/2017/08/IMG_20170827_200313_185.jpg'),
           ('Willow', 'https://www.gannett-cdn.com/presto/2023/02/10/PDTF/8883e611-7a85-4d75-8663-5d5e42eea0a6-02032023_willow-17.jpg'),
           ('Windtalker', 'http://www.completecocktails.com/img/d/l/Windtalker.jpg'),
           ('Winter Season', 'https://hips.hearstapps.com/hmg-prod/images/211112-delish-seo-and-holiday-cranberry-whiskey-sour-horizontal-0238-eb-1638468912.jpg'),
           ('Winter Swizzle', 'https://www.thefoodlens.com/uploads/2017/07/BAR-MEZZANA_CAPELLETTI-SWIZZLE_COTW_BRIAN-SAMUELS-PHOTOGRAPHY_JUNE-2017-2850-1200x800.jpg'),
           ('Xmas in Juniper', 'https://ritzymom.com/wp-content/uploads/2018/12/img_7691.jpg'),
           ('Yawkey Way', 'https://www.thedailymeal.com/img/gallery/gatsby-inspired-gin-cocktails-slideshow/644655.jpg'),
           ('Yes, Queen!', 'https://spiritedzine.com/wp-content/uploads/2022/05/Pass-the-Crown-2.jpg'),
           ('You Bet Your Ascot', 'https://www.brooklynpaper.com/wp-content/uploads/2014/10/24-brooklyn-spirits-recipes-2014-10-17-bk01_z.jpg'),
           ('You Go Glen Coco', 'https://www.caligirlcooking.com/wp-content/uploads/2016/03/You-Go-Gin-Coco-30.jpg'),
           ("You're Bitter Than That", 'https://talesofthecocktail.org/wp-content/uploads/2016/11/bitter-than-that.jpg'),
           ('Ypioca Chile Punch', 'https://barefeetinthekitchen.com/wp-content/uploads/2013/08/caipirinha-4.jpg'),
           ('Ypioca Yellow Card', 'https://www.mantitlement.com/wp-content/uploads/2017/11/spicy-pineapple-cilantro-margarita-front-300x300.jpg'),
           ('“Prepare for Destiny! Where’s my Pizza?”', 'https://blog.saucey.com/wp-content/uploads/2018/01/dsc00647-scaled.jpg')
        
          ]
    for name, link in lst:
        data.loc[data['drink_name'] == name, 'picture'] = link
    
    return data

# %%
data = add_picture_links(data)
data
# Out:
#                                     drink_name  \
# 0                                #106 Cocktail
# 1         '57 Chevy with a White License Plate
# 2                               1-900-FUK-MEUP
# 3                                      10 to 7
# 4                             110 in the shade
# ...                                        ...
# 1712                                    Zoksel
# 1713                                    Zombie
# 1714                                 Zorbatini
# 1715                                     Zorro
# 1716  “Prepare for Destiny! Where’s my Pizza?”
#
#                                            instructions  steps  \
# 0     Shake and double strain into a coupe. Garnish ...      4
# 1     1. Fill a rocks glass with ice 2.add white cre...      3
# 2     Shake ingredients in a mixing tin filled with ...      2
# 3     Shake and serve up in a martini glass with lem...      1
# 4                 Drop shooter in glass. Fill with beer      1
# ...

# %% [markdown]
# ### Adding Tags

# %%
#Drinks to find tags for
data[pd.isna(data['tags'])]['drink_name']
# Out:
# 546           Down the Rabbit Hole
# 549                  Drink Lab #16
# 551               Drops of Jupiter
# 553             Dry Mauritian Sour
# 558     Duke's Classic Dry Martini
#                    ...
# 1339                     Shadowcat
# 1347                   Short Round
# 1348                Short Round II
# 1351            Shroud of the Inca
# 1354                    Sidewinder
# Name: drink_name, Length: 302, dtype: object

# %%
def add_tags(data):
    
    lst = [('#106 Cocktail', 'cocktail white'),
           ('10 to 7', 'martini yellow'),
           ("1880's Americana", 'short orange'),
           ("20th Century", 'yellow citrus'),
           ('3 & Tree', 'brown short'),
           ('3 Degrees', 'yellow cocktail citrus'),
           ('3AM', 'clear citrus longdrink'),
           ('50/50 Split', 'martini citrus clear'),
           ('7th Heaven', 'cocktail white citrus'),
           ('A Bloody Shame', 'orange cocktail'),
           ('A Botanical Garden', 'white citrus cocktail'),
           ('A Gift from Zara', 'clear bitter cocktail'),
           ('A Love Song', 'bitter red cocktail'),
           ('A Mi Manera (My Way) Pisco Punch', 'citrus cocktail yellow punch'),
           ('A Regal Air', 'short clear citrus'),
           ('A Southern Jackass', 'red'),
           ('A Tall Tell', 'yellow longdrink citrus'),
           ('A.Nise', 'yellow cocktail citrus'),
           ('Abano Sour', 'short brown'),
           ('Above My Pay Grade', 'longdrink orange'),
           ('Abrazo Latino', 'yellow cocktail'),
           ('Across The Pond', 'blue cocktail'),
           ('Adriatique', 'fresh red bitter'),
           ('Almond Brother', 'yellow citrus'),
           ('Almond Crusta', 'yellow citrus'),
           ('Amaretto Bourbon Punch', 'punch orange citrus'),
           ('Amaretto Jello Shot, Why Not', 'red shot'),
           ('Amaretto Sour (Modern)', 'short orange'),
           ('Amaretto Sour BV-Style', 'short orange citrus'),
           ('Amaretto Sourball', 'shot orange citrus'),
           ('Americana Fizz (Layered Cocktail)', 'red longdrink'),
           ('And The Cherry On Top Is...', 'red longdrink'),
           ('Andy Warhol', 'brown cocktail'),
           ('Angel Face (Classic)', 'orange cocktail'),
           ("Angel's Face", 'orange cocktail'),
           ('Aperitivo Spritz', 'orange citrus'),
           ('Apple Shrub Spritz', 'yellow cocktail'),
           ('Apples & Grapes', 'yellow cocktail'),
           ('Apricot Blush', 'orange cocktail'),
           ('Arapa Cocktail', 'shot orange'),
           ('Army and Navy', 'cocktail orange citrus'),
           ('Asian Affair', 'red cocktail'),
           ('Assemble Mule', 'clear cocktail'),
           ('Astoria', 'yellow cocktail'),
           ('Aviation (Adapted)', 'purple cocktail'),
           ('B and B', 'orange'),
           ('B-String', 'brown shot'),
           ("Bachelor's Bait", 'red cocktail'),
           ('Bacio Romana', 'brown cocktail'),
           ('Baile de Verano', 'red citrus cocktail'),
           ('Bajo Control', 'brown'),
           ('Bakko & Zengo', 'brown longdrink'),
           ("Banana's Froster", 'yellow cocktail'),
           ('Barbary Coast Bulldog', 'brown'),
           ('Barrel Aged Ginger Negroni', 'orange'),
           ('Basil Gin and Tonic', 'white cocktail'),
           ('Basilway Daquiri', 'yellow cocktail'),
           ('Bay City Shandy', 'clear longdrink'),
           ('Beachcomber', 'yellow cocktail'),
           ("Bee's Knees", 'yellow cocktail'),
           ('Bella Luna', 'blue cocktail'),
           ('Bianco Americano', 'yellow cocktail citrus'),
           ('Big and Bright', 'yellow cold cocktail'),
           ('Bijou', 'brown cocktail'),
           ('Bird On', 'yellow cocktail'),
           ('Bird is the Word', 'yellow martini'),
           ('Bird on a Wire', 'cocktail'),
           ('Bird to Buck', 'orange cocktail'),
           ('Bitter Mimosa', 'yellow longdrink bitter citrus'),
           ('Bitter Valencia', 'orange citrus martini'),
           ('Black Jam', 'cocktail purple'),
           ('Blind Luck', 'pink longdrink'),
           ('Blinker', 'orange cocktail'),
           ('Blood & Sand', 'sweet red'),
           ('Blood and Sand', 'sweet red'),
           ('Bloody Fernet', 'red cocktail citrus'),
           ('Bloody Swede', 'red longdrink'),
           ('Blue 88', 'blue cocktail'),
           ('Bobby Burns', 'brown cocktail'),
           ('Boko Buku', 'pink cocktail'),
           ('Bon Voyage Pisco Punch', 'pink punch'),
           ("Boomin' Granny", 'orange cocktail'),
           ('Boulevard', 'short brown bitter sweet'),
           ('Boulevardier', 'short brown bitter sweet'),
           ('Bourbon Crusta', 'orange cocktail'),
           ('Brazilian Mai Tai', 'orange citrus cocktail'),
           ('Brazilian Mule Punch', 'pink punch'),
           ('Brisa del Sur', 'orange short'),
           ('Bubbleliciously Delicious', 'pink sweet cocktail'),
           ('Bubbly Bird', 'orange longdrink'),
           ('Buenaventura', 'orange cocktail'),
           ('Bunny Poison', 'sweet orange cocktail'),
           ('Bushido Cocktail', 'yellow cocktail'),
           ('Buster Crusta', 'orange martini'),
           ('Buttermilk maple gin flip', 'yellow cocktail sweet'),
           ("Buzzard's Bay", 'red cocktail'),
           ('Cafe Creole', 'brown coffee cocktail'),
           ("California's Callin'", 'yellow longdrink'),
           ('Canary vs. the Coal Mine', 'yellow martini'),
           ("Cap't of the Seven Seas", 'blue martini'),
           ('Carrier Pigeon (an Airmail with Pink Pigeon)', 'shot red'),
           ('Champs Élysées', 'yellow cocktail citrus'),
           ('Chapman Cobbler', 'orange short citrus'),
           ('Charente Royale', 'red cocktail'),
           ('Cherries St. James', 'red cocktail'),
           ('Cherry Bark Martinez', 'red cocktail'),
           ('Cherry Blossom Martini', 'pink sweet martini'),
           ('Cherry Champagne Cocktail', 'pink sparkling'),
           ('Cherry Old Fashioned', 'orange short'),
           ('Cherry Orchard', 'red cocktail'),
           ('Cherry Shandy', 'orange cocktail'),
           ('Chilcano', 'yellow cocktail'),
           ('Chilcano (variation)', 'yellow cocktail'),
           ('Chilli Vanilli', 'green cocktail'),
           ('Chingerito', 'red cocktail'),
           ('Chippendale Rosetone', 'orange cocktail'),
           ('Château Montifaud Creation', 'orange martini'),
           ('Château Montifaud Lady Touch Triple Sec', 'pink cocktail'),
           ('Château Montifaud Pink Love', 'pink cocktail'),
           ('Château Montifaud on Mint', 'orange longdrink'),
           ('Château Montifaud on the Rocks', 'orange short'),
           ('Citrus Agave Caipirinha', 'clear short citrus'),
           ('Citrus Quo (Adapted)', 'orange citrus short'),
           ('Classic Lolita', 'red cocktail'),
           ('Clear Intentions', 'clear shot'),
           ('Clearly Bitter', 'bitter clear'),
           ('Clover Holiday Cocktail', 'red cocktail'),
           ('Club Med', 'yellow cocktail'),
           ('Cocao Martini', 'brown martini'),
           ('Cock-tail', 'orange cocktail'),
           ('Coco Batida', 'white cocktail'),
           ('Coffee & Clove', 'brown short'),
           ('Coffey Grain Manhattan', 'coffee brown citrus cocktail'),
           ('Conference', 'orange citrus longdrink'),
           ('Coos Bay', 'orange citrus cocktail'),
           ('Corpse Reviver No 1', 'brown martini'),
           ('Corpse Reviver No.2', 'yellow martini'),
           ('Cream of the Crop', 'yellow longdrink'),
           ('Creek Ran Dry', 'yellow citrus short'),
           ('Creole', 'brown cocktail citrus'),
           ('Creole Cobbler', 'yellow short'),
           ('Creole Summer', 'yellow short'),
           ('Croatia Firing Squad', 'red longdrink'),
           ('Crooked Kilt', 'frozen yellow short'),
           ('Cuba Liberation', 'brown short'),
           ('Culebra', 'orange longdrink'),
           ('Cullerton Street', 'yellow short'),
           ("Cupid's Carrier Pigeon", 'pink cocktail'),
           ('Cut & Rum', 'brown martini'),
           ('Cut To The Chase', 'red short'),
           ('Cut and Run', 'pink cocktail'),
           ('Cynar Toronto', 'brown short'),
           ('Cynartown', 'brown cocktail'),
           ('Daisy Mae', 'yellow cocktail'),
           ('Day For Night', 'orange longdrink'),
           ('Delicious Sour', 'yellow martini'),
           ('Delicious in Mauritius', 'yellow cocktail'),
           ('Derby cocktail', 'brown martini'),
           ('Dernier Mot', 'brown martini'),
           ("Desmond's Choice", 'green martini'),
           ('Deviled Negroni', 'red short'),
           ('Dirt Nap', 'orange shot'),
           ('Divine Aspect', 'pink longdrink'),
           ('Division Bell', 'orange martini'),
           ("Doctor's Orders", 'orange short'),
           ("Don't Rock the Boat Punch", 'punch orange citrus'),
           ('Donaji', 'yellow short'),
           ('Double Trouble', 'yellow short'),
           ('Simply Perfecto', 'wine orange ice'),
           ('Singapore Sling (1915 Recipe)', 'gin pineapple citrus red'),  
           ('Sloe & Steady', 'gin red'),
           ('Slow Ride', 'rum ginger citrus brown'),
           ('Smashing Great Pumpkins', 'pumpkin orange vodka'),
           ('Smoke On The Dock', 'lime red highball'),
           ('Snow Bunny', 'christmas brown beer'),
           ('Soleo', 'citrus yellow'),
           ('Solera Sidecar', 'brown cognac lemon'),
           ('Sorrentino', 'lemon bitter yellow'),
           ('Sorriso (Adapted)', 'red gin vodka cherry'),
           ('Space Age Pop', 'cherry lemon ice'),
           ('Spanish G&T', 'floral gin white'),
           ('Speyside Orchard', 'floral lemon white bourbon'),
           ('Spice and Stormy', 'pineapple brown rum ginger'),
           ('Spiced Marmalade', 'lemon gin orange'),
           ('Spring Cleanse', 'red fruit'),
           ('Spring Forward', 'gin pineapple brown'),
           ('Still Life of a Pineapple', 'yellow pineapple'),
           ('Stone Fruit Patch V1', 'fruit citrus red'),
           ('Stone Fruit Patch V2', 'fruit citrus red'),
           ('Stranger in the Alps', 'gin cocktail ice'),
           ('Strike No.3', 'gin citrus brown'),
           ('Stroll Through the Park', 'mint citrus white'),
           ('Swedish 75', 'citrus red vodka'),
           ('Swedish Nightingale', 'gin pineapple brown'),
           ('Swedish Royal', 'brown vodka fruit'),
           ('Tahitian Fix', 'highball citrus white'),
           ('Tamaulipas Margarita', 'tequila ice citrus white'),
           ('Tambourine', 'vodka yellow pineapple citrus'),
           ('Tea & Sympathy', 'citrus tea yellow'),
           ('Tea Party Cocktail', 'gin orange cocktail'),
           ('Temple of the Moon', 'orange floral gin clear'),
           ('Tequila Sunflare', 'tequila red fruit'),
           ('The 42nd Round', 'gin citrus clear ice'),
           ('The Alpine Mist', 'ginger fruit black'),
           ('The Asterisk', 'green citrus'),
           ('The Awen', 'orange ice'),
           ('The Bacchus Cocktail', 'cocktail fruit black citrus'),
           ('The Big Picture', 'ice citrus red'),
           ('The Bitter King', 'martini brown citrus'),
           ('The Bittered Valley', 'red bitter'),
           ('The Bossa Nova', 'sweet fruit yellow'),
           ('The Boys of Summer Cup', 'highball gin orange'),
           ('The Brightside', 'orange citrus cream'),
           ('The Callas Cocktail', 'rose clear gin cocktail'),
           ('The Canevari Cocktail', 'cocktail gin orange'),
           ('The Cappa', 'cocktail red'),
           ('The Cavalier White Lady', 'gin white citrus'),
           ('The Chief', 'brown gin cherry'),
           ('The Claridge', 'gin fruit brown'),
           ('The Cliffdiver', 'blue cocktail floral'),
           ("The Commissioner's Trophy #3", 'gin brown fruit'),
           ('The Double Crown', 'brown citrus'),
           ('The Douglas Tilden', 'clear floral cocktail'),
           ('The Fall 75', 'clear sparkling citrus'),
           ('The French Connection', 'brown fruit'),
           ('The Fritz', 'citrus clear'),
           ('The Ginger Royale', 'champagne brown'),
           ('The Great Pumpkin Cocktail', 'orange cocktail'),
           ('The Happy Place', 'red fruit gin'),
           ('The Hollinger Manhattan', 'brown sweet'),
           ('The House of Duncan', 'cherry orange ice'),
           ('The Improved Sazerac', 'brown bitter'),
           ('The Inside Job', 'brown cherry'),
           ('The Italian Diplomat', 'clear cocktail'),
           ('The King Merlet Sidecar', 'brown ice citrus'),
           ('The King and Tonic', 'highball brown'),
           ("The King's Autumn Cobbler", 'black fruit'),
           ("The King's Cranberry Sauce", 'red fruit berry'),
           ("The King's Egg Nog", 'cream spice gin brown'),
           ("The King's Froth & Frizz", 'brown citrus fruit'),
           ("The King's Ginger Spiced Punch", 'red berry fruit'),
           ("The King's Ginger Summer Cup", 'berry red citrus ice'),
           ("The King's Medicine", 'ice citrus brown'),
           ("The King's Mulled Cider", 'brown fruit'),
           ("The King's Mulled Wine", 'red wine citrus'),
           ("The King's Queen", 'ginger citrus brown'),
           ("The King's Spring Daisy", 'citrus cocktail brown'),
           ("The King's Squeeze", 'citrus ginger brown'),
           ("The King's Winter Cup", 'cinnamon ginger fruit brown'),
           ('The Kings Mule', 'ginger brown citrus'),
           ('The Lady Whisper', 'ice rum brown fruit'),
           ('The Ladybird', 'brown rum cherry'),
           ('The Last Marasca', 'gin cherry red'),
           ('The Last Tango', 'floral gin red'),
           ('The Last Wish', 'cream coffee brown'),
           ("The Lover's Quarrel", 'ice fruit gin brown'),
           ('The Mad King', 'highball ginger brown'),
           ('The Mayan Premonition', 'clear tequila'),
           ('The Molino', 'ice brown cherry'),
           ('The Monte Rua', 'sparkling cherry red'),
           ('The Naughty & Nice', 'pumpkin spice brown'),
           ('The No.3 Winter Cup', 'red gin ginger'),
           ('The No.3 Winter Punch', 'gin ginger red'),
           ('The Nutty Sensation', 'nut gin brown'),
           ('The Palace Cellar', 'highball brown gin'),
           ('The Pink Aperitivo', 'red martini'),
           ('The Pink Pussycat', 'sweet red cream berry'),
           ('The Professor', 'coffee brown nut'),
           ('The Proverb', 'brown cherry'),
           ('The Queen Mother', 'brown gin'),
           ("The Queen's A Redhead", 'brown ginger citrus'),
           ('The Red Anchor', 'pink gin fruit'),
           ('The Reserved King', 'citrus brown'),
           ('The Rickenbacker', 'cocktail vodka clear'),
           ('The Robert Baratheon', 'brown scotch'),
           ('The Royal Buck', 'brown gin citrus'),
           ('The Royal King', 'ginger brown champagne'),
           ('The Rusty Tack', 'brown ginger'),
           ('The Seniorita', 'ice coconut citrus'),
           ('The Silver Cocktail', 'cocktail citrus gin clear'),
           ('The Sixth Sense', 'coconut pineapple yellow'),
           ('The Southside', 'citrus gin brown'),
           ('The Sparkler', 'grapefruit white'),
           ('The Stand By', 'gin coconut clear'),
           ('The Sun Also Rises', 'citrus rum fruit'),
           ('The Swedish', 'vodka brown spice'),
           ('The Tahoe Toddy', 'citrus clove brown'),
           ('The Touch  of Glass', 'brown brandy'),
           ('The Twinger', 'ginger highball brown'),
           ('The Windtalker', 'bourbon brown citrus'),
           ('Three Flips', 'gin brown honey'),
           ('Thyme for Bed', 'red citrus'),
           ('Toasted Drop', 'cocktail citrus yellow'),
           ('Tokyo Tea', 'brown coffee cream'),
           ('Trato Hecho', 'pineapple green citrus'),
           ('Trip to Jarnac', 'orange citrus'),
           ('Tropical Bronzer', 'rum cocktail red'),
           ('Under the Sun', 'rum pineapple, yellow'),
           ('Venetian', 'orange fruit'),
           ("Vesper's Sister", 'martini citrus orange gin'),
           ('Vida Verde (Adapted)', 'green citrus'),
           ('Vieja Moda', 'citrus brown tequila'),
           ('Vieux Carré', 'whiskey bitters cocktail brown'),
           ('Vintage Reserve Sour', 'orange fruit citrus'),
           ('Vinterpäls', 'vodka honey orange'),
           ('Virgil St.', 'brown ice gin'),
           ('Wabash Avenue Sour', 'red citrus'),
           ('War of the Roses', 'gin lemon orange'),
           ('West Bank', 'spice coffee brown'),
           ('West Coast Punch', 'yellow lemon gin'),
           ('West Coast Vesper', 'white vodka gin'),
           ("Where's the Orgeat?", 'white citrus'),
           ('White Lady (Classic) (Adapted)', 'white gin citrus'),
           ('White Tie', 'white cocktail gin'),
           ('White Walker Flip', 'whiskey blue'),
           ('Willow', 'lemon gin orange'),
           ('Windtalker', 'brown lemon ice'),
           ('Winter Season', 'gin blue'),
           ('Winter Swizzle', 'mint lime rum orange'),
           ('Xmas in Juniper', 'beer gin citrus brown'),
           ('Yawkey Way', 'highball gin red fruit'),
           ('Yes, Queen!', 'brown honey'),
           ('You Bet Your Ascot', 'brown citrus'),
           ('You Go Glen Coco', 'coconut yellow'),
           ("You're Bitter Than That", 'ice tequila red'),
           ('Ypioca Chile Punch', 'brown pineapple citrus'),
           ('Ypioca Yellow Card', 'yellow pineapple'),
           ('“Prepare for Destiny! Where’s my Pizza?”', 'gin citrus red')
          ]
    for name, tags in lst:
        data.loc[data['drink_name'] == name, 'tags'] = tags
    return data

# %%
data = add_tags(data)
data
# Out:
#                                     drink_name  \
# 0                                #106 Cocktail
# 1         '57 Chevy with a White License Plate
# 2                               1-900-FUK-MEUP
# 3                                      10 to 7
# 4                             110 in the shade
# ...                                        ...
# 1712                                    Zoksel
# 1713                                    Zombie
# 1714                                 Zorbatini
# 1715                                     Zorro
# 1716  “Prepare for Destiny! Where’s my Pizza?”
#
#                                            instructions  steps  \
# 0     Shake and double strain into a coupe. Garnish ...      4
# 1     1. Fill a rocks glass with ice 2.add white cre...      3
# 2     Shake ingredients in a mixing tin filled with ...      2
# 3     Shake and serve up in a martini glass with lem...      1
# 4                 Drop shooter in glass. Fill with beer      1
# ...

# %%
data.to_csv('tags.csv')
